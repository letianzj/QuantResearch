# %%
'''
	It is based off of Mebane Faber's "Global Tactical Asset Allocation" (GTAA). GTAA consists of five global asset
    classes:  US stocks, foreign stocks, bonds, real estate and commodities...it is either long the asset class or in cash
    with its allocation of the funds.

    The basics of the strategy go like this:
    https://www.quantopian.com/posts/meb-fabers-global-tactical-asset-allocation-gtaa-strategy
    (1) Look at a 200 day or 10 months trailing window (SA - Slow Average) versus a 20 day trailing window (FA - Fast Average).
    (2) If the FA is greater than the SA, go long about 20% of your portfolio in that security
    (3) If the FA is less than the SA, have 0% of your portfolio in that security; hold cash instead
    The system updates monthly at the end of the month.

    In this historical bull markets, nothing beats simply holding SPY. But the strategy didn't beat naive diversification 20% holdings.
    It avoid downturn end of 2015 by holding all cash; yet missed wave 3 that began at 2016.
'''
import os
import numpy as np
import pandas as pd
from datetime import datetime
import backtrader as bt
from IPython.core.display import display, HTML
# set browser full width
display(HTML("<style>.container { width:100% !important; }</style>"))


class EndOfMonth(object):
    def __init__(self, cal):
        self.cal = cal

    def __call__(self, d):
        if self.cal.last_monthday(d):
            return True
        return False


class MebaneFaberTAA(bt.Strategy):
    params = (
        ('nslow', 200),
        ('nfast', 20),
        ('printlog', False),        # comma is required
    )

    def __init__(self):
        self.buyprice = None
        self.buycomm = None
        self.bar_executed = None
        self.val_start = None

        self.add_timer(
            when=bt.Timer.SESSION_START,       # before next
            allow=EndOfMonth(cal = bt.TradingCalendar())
        )

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function fot this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' % (trade.pnl, trade.pnlcomm))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:                # order.Partial
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                    (order.executed.price,
                     order.executed.size,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.remsize,
                     self.broker.get_cash()))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                         (order.executed.price,
                          order.executed.size,
                          order.executed.value,
                          order.executed.comm,
                          order.executed.remsize,
                          self.broker.get_cash()))

            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Expired, order.Margin, order.Rejected]:
            self.log('Order Failed')

    def next(self):
        pass

    def notify_timer(self, timer, when, *args, **kwargs):
        print('{} strategy notify_timer with tid {}, when {} cheat {}'.
              format(self.data.datetime.datetime(), timer.p.tid, when, timer.p.cheat))
        if len(self.datas[0]) < self.p.nslow:       # not enough bars
            return

        total_value = self.broker.getvalue()
        stock_value = total_value * 0.95 / 5
        for data in self.datas:
            pos = self.getposition(data).size
            ma_fast = np.mean(data.get(0, self.p.nfast))
            ma_slow = np.mean(data.get(0, self.p.nslow))
            if ma_fast > ma_slow:         # buy
                target_pos = (int)(stock_value / data.close[0])
                self.order_target_size(data=data, target=target_pos)
                self.log('LONG ORDER SENT, %s, Price: %.2f, fast sma: %.2f, slow sma: %.2f, Size: %.2f' %
                         (data._name,
                          data.close[0],
                          ma_fast,
                          ma_slow,
                          target_pos))
            else:       # hold cash
                target_pos = 0
                self.order_target_size(data=data, target=target_pos)
                self.log('FLAT ORDER SENT, %s, Price: %.2f, fast sma: %.2f, slow sma: %.2f, Size: %.2f' %
                         (data._name,
                          data.close[0],
                          ma_fast,
                          ma_slow,
                          target_pos))

    def stop(self):
        # calculate the actual returns
        print(self.analyzers)
        roi = (self.broker.get_value() / self.val_start) - 1.0
        self.log('ROI:        {:.2f}%'.format(100.0 * roi))
        self.log('(Mebane Faber TAA Ending Value %.2f' %
                  self.broker.getvalue(), doprint=True)


if __name__ == '__main__':
    param_opt = False
    perf_eval = True
    initial_capital = 100000.0
    etfs = ['SPY', 'EFA', 'TIP', 'GSG', 'VNQ']
    benchmark = etfs

    cerebro = bt.Cerebro()

    # Add the Data Feed to Cerebro
    # SPY: S&P 500
    # EFA: MSCI EAFE
    # TIP: UST
    # GSG: GSCI
    # VNQ: REITs
    for s in etfs:
        # Create a Data Feed
        data = bt.feeds.YahooFinanceCSVData(
            dataname=os.path.join('../data/', f'{s}.csv'),
            fromdate=datetime(2010, 1, 1),
            todate=datetime(2019, 12, 31),
            reverse=False)
        cerebro.adddata(data, name=s)

    # Set our desired cash start
    cerebro.broker.setcash(initial_capital)

    # Add a FixedSize sizer according to the stake
    # cerebro.addsizer(bt.sizers.FixedSize, stake=10)
    # PercentSizer will flat position first; overwrite if not desired.
    # cerebro.addsizer(bt.sizers.PercentSizerInt, percents=95)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Add a strategy
    cerebro.addstrategy(MebaneFaberTAA, printlog=True)

    # Add Analyzer
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='SharpeRatio')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DrawDown')
    cerebro.addanalyzer(bt.analyzers.PositionsValue, _name='positions', cash=True)
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

    # Run over everything
    results = cerebro.run()

    # Print out the final result
    strat = results[0]
    print('Final Portfolio Value: %.2f, Sharpe Ratio: %.2f, DrawDown: %.2f, MoneyDown %.2f' %
          (cerebro.broker.getvalue(),
           strat.analyzers.SharpeRatio.get_analysis()['sharperatio'],
           strat.analyzers.DrawDown.get_analysis()['drawdown'],
           strat.analyzers.DrawDown.get_analysis()['moneydown']))

    if perf_eval:
        import matplotlib.pyplot as plt
        cerebro.plot(style='candlestick')
        plt.show()

        pyfoliozer = strat.analyzers.getbyname('pyfolio')
        returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
        # somehow pyfolio analyzer doesn't handle well multi-assets
        df_positions = pd.DataFrame.from_dict(strat.analyzers.positions.get_analysis(), orient='index')
        df_positions.columns = etfs+['cash']

        print('-------------- RETURNS ----------------')
        print(returns)
        print('-------------- POSITIONS ----------------')
        print(df_positions)
        print('-------------- TRANSACTIONS ----------------')
        print(transactions)
        print('-------------- GROSS LEVERAGE ----------------')
        print(gross_lev)

        import empyrical as ep
        import pyfolio as pf

        bm_ret = None
        returns = returns[transactions.index[0]:]  # count from first trade
        # returns.index = returns.index.tz_localize(None)  # # remove tzinfo; tz native
        df_positions.index = df_positions.index.map(lambda x: datetime.combine(x, datetime.min.time()))
        df_positions.index = df_positions.index.tz_localize('UTC')
        df_positions = df_positions.loc[returns.index]

        df_constituents = pd.DataFrame()
        for s in ['SPY', 'EFA', 'TIP', 'GSG', 'VNQ']:
            datapath = os.path.join('../data/', f'{s}.csv')
            df_temp = pd.read_csv(datapath, index_col=0)
            df_temp = df_temp['Adj Close']
            df_temp.name = s
            df_constituents = pd.concat([df_constituents, df_temp], axis=1)

        df_constituents_ret = df_constituents.pct_change()
        df_constituents_ret.index = pd.to_datetime(df_constituents_ret.index)
        df_constituents_ret.index = df_constituents_ret.index.tz_localize('UTC')
        df_constituents_ret = df_constituents_ret.loc[returns.index]
        df_constituents_ret['Benchmark'] = df_constituents_ret.mean(axis=1)  # 20% each
        df_constituents_value = initial_capital * (df_constituents_ret + 1).cumprod()

        perf_stats_strat = pf.timeseries.perf_stats(returns)
        perf_stats_bm = pf.timeseries.perf_stats(df_constituents_ret.Benchmark)
        perf_stats_all = pd.concat([perf_stats_strat, perf_stats_bm], axis=1)
        perf_stats_all.columns = ['Strategy', 'Benchmark']

        drawdown_table = pf.timeseries.gen_drawdown_table(returns, 5)
        monthly_ret_table = ep.aggregate_returns(returns, 'monthly')
        monthly_ret_table = monthly_ret_table.unstack().round(3)
        ann_ret_df = pd.DataFrame(ep.aggregate_returns(returns, 'yearly'))
        ann_ret_df = ann_ret_df.unstack().round(3)
        print('-------------- PERFORMANCE ----------------')
        print(perf_stats_all)
        print('-------------- DRAWDOWN ----------------')
        print(drawdown_table)
        print('-------------- MONTHLY RETURN ----------------')
        print(monthly_ret_table)
        print('-------------- ANNUAL RETURN ----------------')
        print(ann_ret_df)

        pf.create_full_tear_sheet(
            returns,
            benchmark_rets=df_constituents_ret['Benchmark'],
            positions=df_positions,
            transactions=transactions,
            #live_start_date='2005-05-01',
            round_trips=False)
        plt.show()

        df_value_all = df_constituents_value.copy()
        # df_value_all =df_constituents_value.merge(df_positions['Total'], how='inner', left_index=True, right_index=True)
        df_value_all['Strategy'] = df_positions.sum(axis=1)
# 2012-02-29, LONG ORDER SENT, EFA, Price: 42.30, fast sma: 41.90, slow sma: 40.81, Size: 474.00
# 2012-02-29, LONG ORDER SENT, TIP, Price: 103.45, fast sma: 103.48, slow sma: 99.59, Size: 193.00
# 2012-02-29, LONG ORDER SENT, GSG, Price: 35.87, fast sma: 34.89, slow sma: 33.78, Size: 559.00
# 2012-02-29, LONG ORDER SENT, VNQ, Price: 43.23, fast sma: 44.02, slow sma: 40.34, Size: 463.00
# 2012-03-01, SELL EXECUTED, Price: 115.84, Size: -7, Cost: 781.20, Comm 0.81, RemSize: 0, RemCash: 5284.90
# 2012-03-01, BUY EXECUTED, Price: 42.53, Size: 474, Cost: 20159.22, Comm 20.16, RemSize: 0, RemCash: 5284.90
# 2012-03-01, BUY EXECUTED, Price: 103.15, Size: 1, Cost: 103.15, Comm 0.10, RemSize: 0, RemCash: 5284.90
# 2012-03-01, BUY EXECUTED, Price: 35.92, Size: 559, Cost: 20079.28, Comm 20.08, RemSize: 0, RemCash: 5284.90
# 2012-03-01, BUY EXECUTED, Price: 43.27, Size: 6, Cost: 259.62, Comm 0.26, RemSize: 0, RemCash: 5284.90
# 2012-03-30 23:59:59.999989 strategy notify_timer with tid 0, when 2012-03-30 00:00:00 cheat False
# 2012-03-30, LONG ORDER SENT, SPY, Price: 119.31, fast sma: 117.76, slow sma: 106.46, Size: 169.00
# 2012-03-30, LONG ORDER SENT, EFA, Price: 42.48, fast sma: 42.32, slow sma: 40.49, Size: 475.00
# 2012-03-30, LONG ORDER SENT, TIP, Price: 102.56, fast sma: 102.76, slow sma: 100.54, Size: 197.00
# 2012-03-30, LONG ORDER SENT, GSG, Price: 34.78, fast sma: 35.57, slow sma: 33.79, Size: 580.00
# 2012-03-30, LONG ORDER SENT, VNQ, Price: 45.47, fast sma: 44.49, slow sma: 40.65, Size: 444.00
# 2012-04-02, SELL EXECUTED, Price: 119.17, Size: -4, Cost: 446.40, Comm 0.48, RemSize: 0, RemCash: 5444.63
# 2012-04-02, BUY EXECUTED, Price: 42.28, Size: 1, Cost: 42.28, Comm 0.04, RemSize: 0, RemCash: 5444.63
# 2012-04-02, BUY EXECUTED, Price: 102.97, Size: 4, Cost: 411.88, Comm 0.41, RemSize: 0, RemCash: 5444.63
# 2012-04-02, BUY EXECUTED, Price: 34.54, Size: 21, Cost: 725.34, Comm 0.73, RemSize: 0, RemCash: 5444.63
# 2012-04-02, SELL EXECUTED, Price: 45.53, Size: -19, Cost: 837.51, Comm 0.87, RemSize: 0, RemCash: 5444.63
# 2012-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2012-04-30 00:00:00 cheat False
# 2012-04-30, LONG ORDER SENT, SPY, Price: 118.52, fast sma: 117.52, slow sma: 107.32, Size: 171.00
# 2012-04-30, LONG ORDER SENT, EFA, Price: 41.60, fast sma: 41.22, slow sma: 40.13, Size: 487.00
# 2012-04-30, LONG ORDER SENT, TIP, Price: 104.39, fast sma: 103.76, slow sma: 101.41, Size: 194.00
# 2012-04-30, LONG ORDER SENT, GSG, Price: 34.66, fast sma: 34.50, slow sma: 33.80, Size: 584.00
# 2012-04-30, LONG ORDER SENT, VNQ, Price: 46.78, fast sma: 45.36, slow sma: 41.00, Size: 433.00
# 2012-05-01, BUY EXECUTED, Price: 118.45, Size: 2, Cost: 236.90, Comm 0.24, RemSize: 0, RemCash: 5399.32
# 2012-05-01, BUY EXECUTED, Price: 41.50, Size: 12, Cost: 498.00, Comm 0.50, RemSize: 0, RemCash: 5399.32
# 2012-05-01, SELL EXECUTED, Price: 104.60, Size: -3, Cost: 275.41, Comm 0.31, RemSize: 0, RemCash: 5399.32
# 2012-05-01, BUY EXECUTED, Price: 34.41, Size: 4, Cost: 137.64, Comm 0.14, RemSize: 0, RemCash: 5399.32
# 2012-05-01, SELL EXECUTED, Price: 46.83, Size: -11, Cost: 484.87, Comm 0.52, RemSize: 0, RemCash: 5399.32
# 2012-05-31 23:59:59.999989 strategy notify_timer with tid 0, when 2012-05-31 00:00:00 cheat False
# 2012-05-31, LONG ORDER SENT, SPY, Price: 111.40, fast sma: 113.38, slow sma: 108.29, Size: 170.00
# 2012-05-31, FLAT ORDER SENT, EFA, Price: 36.96, fast sma: 38.55, slow sma: 39.67, Size: 0.00
# 2012-05-31, LONG ORDER SENT, TIP, Price: 106.42, fast sma: 105.27, slow sma: 102.17, Size: 178.00
# 2012-05-31, FLAT ORDER SENT, GSG, Price: 30.23, fast sma: 31.89, slow sma: 33.54, Size: 0.00
# 2012-05-31, LONG ORDER SENT, VNQ, Price: 44.67, fast sma: 45.58, slow sma: 41.57, Size: 425.00
# 2012-06-01, SELL EXECUTED, Price: 109.65, Size: -1, Cost: 111.68, Comm 0.11, RemSize: 0, RemCash: 42444.45
# 2012-06-01, SELL EXECUTED, Price: 36.32, Size: -487, Cost: 20699.50, Comm 17.69, RemSize: 0, RemCash: 42444.45
# 2012-06-01, SELL EXECUTED, Price: 106.54, Size: -16, Cost: 1468.84, Comm 1.70, RemSize: 0, RemCash: 42444.45
# 2012-06-01, SELL EXECUTED, Price: 29.50, Size: -584, Cost: 20942.26, Comm 17.23, RemSize: 0, RemCash: 42444.45
# 2012-06-01, SELL EXECUTED, Price: 44.01, Size: -8, Cost: 352.63, Comm 0.35, RemSize: 0, RemCash: 42444.45
# 2012-06-01, OPERATION PROFIT, GROSS -3011.66, NET -3050.05
# 2012-06-01, OPERATION PROFIT, GROSS -3714.26, NET -3752.43
# 2012-06-29 23:59:59.999989 strategy notify_timer with tid 0, when 2012-06-29 00:00:00 cheat False
# 2012-06-29, LONG ORDER SENT, SPY, Price: 115.92, fast sma: 112.81, slow sma: 109.78, Size: 165.00
# 2012-06-29, FLAT ORDER SENT, EFA, Price: 39.56, fast sma: 37.89, slow sma: 39.52, Size: 0.00
# 2012-06-29, LONG ORDER SENT, TIP, Price: 105.71, fast sma: 106.11, slow sma: 102.81, Size: 181.00
# 2012-06-29, FLAT ORDER SENT, GSG, Price: 30.44, fast sma: 29.45, slow sma: 33.10, Size: 0.00
# 2013-02-01, SELL EXECUTED, Price: 129.91, Size: -4, Cost: 447.56, Comm 0.52, RemSize: 0, RemCash: 5509.27
# 2013-02-01, SELL EXECUTED, Price: 47.52, Size: -6, Cost: 244.56, Comm 0.29, RemSize: 0, RemCash: 5509.27
# 2013-02-01, BUY EXECUTED, Price: 107.91, Size: 5, Cost: 539.55, Comm 0.54, RemSize: 0, RemCash: 5509.27
# 2013-02-01, BUY EXECUTED, Price: 34.29, Size: 591, Cost: 20265.39, Comm 20.27, RemSize: 0, RemCash: 5509.27
# 2013-02-01, SELL EXECUTED, Price: 50.43, Size: -6, Cost: 265.20, Comm 0.30, RemSize: 0, RemCash: 5509.27
# 2013-02-28 23:59:59.999989 strategy notify_timer with tid 0, when 2013-02-28 00:00:00 cheat False
# 2013-02-28, LONG ORDER SENT, SPY, Price: 130.74, fast sma: 130.44, slow sma: 120.89, Size: 154.00
# 2013-02-28, LONG ORDER SENT, EFA, Price: 46.61, fast sma: 46.79, slow sma: 42.17, Size: 432.00
# 2013-02-28, FLAT ORDER SENT, TIP, Price: 107.87, fast sma: 107.43, slow sma: 107.45, Size: 0.00
# 2013-02-28, LONG ORDER SENT, GSG, Price: 32.54, fast sma: 33.84, slow sma: 32.64, Size: 619.00
# 2013-02-28, LONG ORDER SENT, VNQ, Price: 50.77, fast sma: 50.66, slow sma: 47.61, Size: 396.00
# 2013-03-01, SELL EXECUTED, Price: 130.29, Size: -3, Cost: 335.67, Comm 0.39, RemSize: 0, RemCash: 25506.82
# 2013-03-01, BUY EXECUTED, Price: 46.27, Size: 3, Cost: 138.81, Comm 0.14, RemSize: 0, RemCash: 25506.82
# 2013-03-01, SELL EXECUTED, Price: 107.81, Size: -188, Cost: 17493.53, Comm 20.27, RemSize: 0, RemCash: 25506.82
# 2013-03-01, BUY EXECUTED, Price: 32.35, Size: 28, Cost: 905.80, Comm 0.91, RemSize: 0, RemCash: 25506.82
# 2013-03-01, SELL EXECUTED, Price: 50.64, Size: -8, Cost: 353.60, Comm 0.41, RemSize: 0, RemCash: 25506.82
# 2013-03-01, OPERATION PROFIT, GROSS 3369.86, NET 3320.69
# 2013-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-04-30 00:00:00 cheat False
# 2013-04-30, LONG ORDER SENT, SPY, Price: 138.31, fast sma: 136.02, slow sma: 125.53, Size: 150.00
# 2013-04-30, LONG ORDER SENT, EFA, Price: 49.59, fast sma: 47.94, slow sma: 44.18, Size: 420.00
# 2013-04-30, LONG ORDER SENT, TIP, Price: 108.96, fast sma: 108.73, slow sma: 107.91, Size: 191.00
# 2013-04-30, FLAT ORDER SENT, GSG, Price: 31.29, fast sma: 31.12, slow sma: 32.96, Size: 0.00
# 2013-04-30, LONG ORDER SENT, VNQ, Price: 55.75, fast sma: 54.29, slow sma: 49.15, Size: 373.00
# 2013-05-01, SELL EXECUTED, Price: 138.01, Size: -4, Cost: 447.56, Comm 0.55, RemSize: 0, RemCash: 26095.40
# 2013-05-01, SELL EXECUTED, Price: 49.64, Size: -12, Cost: 489.58, Comm 0.60, RemSize: 0, RemCash: 26095.40
# 2013-05-01, BUY EXECUTED, Price: 109.02, Size: 191, Cost: 20822.82, Comm 20.82, RemSize: 0, RemCash: 26095.40
# 2013-05-01, SELL EXECUTED, Price: 30.73, Size: -619, Cost: 21171.19, Comm 19.02, RemSize: 0, RemCash: 26095.40
# 2013-05-01, SELL EXECUTED, Price: 55.83, Size: -23, Cost: 1016.60, Comm 1.28, RemSize: 0, RemCash: 26095.40
# 2013-05-01, OPERATION PROFIT, GROSS -2149.32, NET -2189.51
# 2013-05-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-05-31 00:00:00 cheat False
# 2013-05-31, LONG ORDER SENT, SPY, Price: 141.58, fast sma: 142.67, slow sma: 128.30, Size: 143.00
# 2013-05-31, LONG ORDER SENT, EFA, Price: 48.09, fast sma: 49.94, slow sma: 45.31, Size: 422.00
# 2013-05-31, FLAT ORDER SENT, TIP, Price: 104.39, fast sma: 106.39, slow sma: 107.84, Size: 0.00
# 2013-05-31, FLAT ORDER SENT, GSG, Price: 30.81, fast sma: 31.43, slow sma: 32.82, Size: 0.00
# 2013-05-31, LONG ORDER SENT, VNQ, Price: 52.42, fast sma: 55.98, slow sma: 50.04, Size: 387.00
# 2013-06-03, SELL EXECUTED, Price: 141.91, Size: -7, Cost: 783.22, Comm 0.99, RemSize: 0, RemCash: 46086.02
# 2013-06-03, BUY EXECUTED, Price: 48.10, Size: 2, Cost: 96.20, Comm 0.10, RemSize: 0, RemCash: 46086.02
# 2013-06-03, SELL EXECUTED, Price: 103.92, Size: -191, Cost: 20822.82, Comm 19.85, RemSize: 0, RemCash: 46086.02
# 2013-06-03, BUY EXECUTED, Price: 52.40, Size: 14, Cost: 733.60, Comm 0.73, RemSize: 0, RemCash: 46086.02
# 2013-06-03, OPERATION PROFIT, GROSS -974.10, NET -1014.77
# 2013-06-28 23:59:59.999989 strategy notify_timer with tid 0, when 2013-06-28 00:00:00 cheat False
# 2013-06-28, LONG ORDER SENT, SPY, Price: 139.69, fast sma: 140.67, slow sma: 130.30, Size: 143.00
# 2013-06-28, LONG ORDER SENT, EFA, Price: 46.80, fast sma: 47.50, slow sma: 45.94, Size: 429.00
# 2013-06-28, FLAT ORDER SENT, TIP, Price: 100.42, fast sma: 101.78, slow sma: 107.37, Size: 0.00
# 2013-06-28, FLAT ORDER SENT, GSG, Price: 30.80, fast sma: 31.31, slow sma: 32.53, Size: 0.00
# 2013-06-28, LONG ORDER SENT, VNQ, Price: 51.38, fast sma: 51.22, slow sma: 50.37, Size: 390.00
# 2013-07-01, BUY EXECUTED, Price: 47.22, Size: 7, Cost: 330.54, Comm 0.33, RemSize: 0, RemCash: 45599.66
# 2013-07-01, BUY EXECUTED, Price: 51.78, Size: 3, Cost: 155.34, Comm 0.16, RemSize: 0, RemCash: 45599.66
# 2013-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-07-31 00:00:00 cheat False
# 2013-07-31, LONG ORDER SENT, SPY, Price: 146.91, fast sma: 145.69, slow sma: 132.62, Size: 139.00
# 2013-07-31, LONG ORDER SENT, EFA, Price: 49.29, fast sma: 48.96, slow sma: 46.61, Size: 416.00
# 2013-07-31, FLAT ORDER SENT, TIP, Price: 101.33, fast sma: 100.74, slow sma: 106.57, Size: 0.00
# 2013-07-31, LONG ORDER SENT, GSG, Price: 32.54, fast sma: 32.58, slow sma: 32.37, Size: 630.00
# 2013-07-31, LONG ORDER SENT, VNQ, Price: 51.84, fast sma: 53.01, slow sma: 50.93, Size: 395.00
# 2013-08-01, SELL EXECUTED, Price: 148.02, Size: -4, Cost: 447.56, Comm 0.59, RemSize: 0, RemCash: 25856.49
# 2013-08-01, SELL EXECUTED, Price: 49.92, Size: -13, Cost: 532.18, Comm 0.65, RemSize: 0, RemCash: 25856.49
# 2013-08-01, BUY EXECUTED, Price: 32.86, Size: 630, Cost: 20701.80, Comm 20.70, RemSize: 0, RemCash: 25856.49
# 2013-08-01, BUY EXECUTED, Price: 52.04, Size: 5, Cost: 260.20, Comm 0.26, RemSize: 0, RemCash: 25856.49
# 2013-08-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-08-30 00:00:00 cheat False
# 2013-08-30, LONG ORDER SENT, SPY, Price: 142.50, fast sma: 145.29, slow sma: 135.26, Size: 141.00
# 2013-08-30, LONG ORDER SENT, EFA, Price: 48.33, fast sma: 49.93, slow sma: 47.43, Size: 416.00
# 2013-08-30, FLAT ORDER SENT, TIP, Price: 99.48, fast sma: 100.15, slow sma: 105.69, Size: 0.00
# 2013-08-30, LONG ORDER SENT, GSG, Price: 33.55, fast sma: 32.96, slow sma: 32.39, Size: 600.00
# 2013-08-30, FLAT ORDER SENT, VNQ, Price: 48.22, fast sma: 49.56, slow sma: 51.23, Size: 0.00
# 2013-09-03, BUY EXECUTED, Price: 143.88, Size: 2, Cost: 287.76, Comm 0.29, RemSize: 0, RemCash: 45678.57
# 2013-09-03, SELL EXECUTED, Price: 33.61, Size: -30, Cost: 985.80, Comm 1.01, RemSize: 0, RemCash: 45678.57
# 2013-09-03, SELL EXECUTED, Price: 48.41, Size: -395, Cost: 17635.74, Comm 19.12, RemSize: 0, RemCash: 45678.57
# 2013-09-03, OPERATION PROFIT, GROSS 2022.71, NET 1976.06
# 2013-09-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-09-30 00:00:00 cheat False
# 2013-09-30, LONG ORDER SENT, SPY, Price: 147.01, fast sma: 147.38, slow sma: 137.96, Size: 138.00
# 2013-09-30, LONG ORDER SENT, EFA, Price: 52.11, fast sma: 51.54, slow sma: 48.27, Size: 392.00
# 2013-09-30, FLAT ORDER SENT, TIP, Price: 101.22, fast sma: 99.64, slow sma: 104.74, Size: 0.00
# 2013-09-30, LONG ORDER SENT, GSG, Price: 32.38, fast sma: 33.09, slow sma: 32.44, Size: 630.00
# 2013-09-30, FLAT ORDER SENT, VNQ, Price: 49.90, fast sma: 49.84, slow sma: 51.57, Size: 0.00
# 2013-10-01, SELL EXECUTED, Price: 147.12, Size: -3, Cost: 337.03, Comm 0.44, RemSize: 0, RemCash: 46407.55
# 2013-10-01, SELL EXECUTED, Price: 52.17, Size: -24, Cost: 982.49, Comm 1.25, RemSize: 0, RemCash: 46407.55
# 2013-10-01, BUY EXECUTED, Price: 32.06, Size: 30, Cost: 961.80, Comm 0.96, RemSize: 0, RemCash: 46407.55
# 2013-10-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-10-31 00:00:00 cheat False
# 2013-10-31, LONG ORDER SENT, SPY, Price: 153.82, fast sma: 150.86, slow sma: 140.95, Size: 134.00
# 2013-10-31, LONG ORDER SENT, EFA, Price: 53.81, fast sma: 53.26, slow sma: 49.14, Size: 384.00
# 2013-10-31, FLAT ORDER SENT, TIP, Price: 101.57, fast sma: 101.31, slow sma: 103.94, Size: 0.00
# 2013-10-31, FLAT ORDER SENT, GSG, Price: 31.91, fast sma: 32.40, slow sma: 32.40, Size: 0.00
# 2013-10-31, FLAT ORDER SENT, VNQ, Price: 52.16, fast sma: 51.78, slow sma: 51.92, Size: 0.00
# 2013-11-01, SELL EXECUTED, Price: 154.02, Size: -4, Cost: 449.37, Comm 0.62, RemSize: 0, RemCash: 67301.08
# 2013-11-01, SELL EXECUTED, Price: 53.52, Size: -8, Cost: 327.50, Comm 0.43, RemSize: 0, RemCash: 67301.08
# 2013-11-01, SELL EXECUTED, Price: 31.54, Size: -630, Cost: 20677.80, Comm 19.87, RemSize: 0, RemCash: 67301.08
# 2013-11-01, OPERATION PROFIT, GROSS -785.10, NET -827.64
# 2013-11-29 23:59:59.999989 strategy notify_timer with tid 0, when 2013-11-29 00:00:00 cheat False
# 2013-11-29, LONG ORDER SENT, SPY, Price: 158.38, fast sma: 156.27, slow sma: 143.60, Size: 131.00
# 2013-11-29, LONG ORDER SENT, EFA, Price: 54.10, fast sma: 53.68, slow sma: 49.82, Size: 383.00
# 2013-11-29, FLAT ORDER SENT, TIP, Price: 100.50, fast sma: 100.72, slow sma: 103.24, Size: 0.00
# 2013-11-29, FLAT ORDER SENT, GSG, Price: 31.76, fast sma: 31.33, slow sma: 32.13, Size: 0.00
# 2013-11-29, FLAT ORDER SENT, VNQ, Price: 49.42, fast sma: 50.55, slow sma: 51.93, Size: 0.00
# 2013-12-02, SELL EXECUTED, Price: 158.46, Size: -3, Cost: 337.03, Comm 0.48, RemSize: 0, RemCash: 67829.85
# 2013-12-02, SELL EXECUTED, Price: 53.92, Size: -1, Cost: 40.94, Comm 0.05, RemSize: 0, RemCash: 67829.85
# 2013-12-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-12-31 00:00:00 cheat False
# 2013-12-31, LONG ORDER SENT, SPY, Price: 162.48, fast sma: 158.72, slow sma: 146.37, Size: 128.00
# 2013-12-31, LONG ORDER SENT, EFA, Price: 55.28, fast sma: 53.51, slow sma: 50.50, Size: 379.00
# 2013-12-31, FLAT ORDER SENT, TIP, Price: 99.04, fast sma: 99.43, slow sma: 102.41, Size: 0.00
# 2013-12-31, LONG ORDER SENT, GSG, Price: 32.19, fast sma: 32.12, slow sma: 32.06, Size: 650.00
# 2013-12-31, FLAT ORDER SENT, VNQ, Price: 49.47, fast sma: 49.33, slow sma: 51.73, Size: 0.00
# 2014-01-02, SELL EXECUTED, Price: 161.86, Size: -3, Cost: 337.03, Comm 0.49, RemSize: 0, RemCash: 47777.19
# 2014-01-02, SELL EXECUTED, Price: 54.55, Size: -4, Cost: 163.75, Comm 0.22, RemSize: 0, RemCash: 47777.19
# 2014-01-02, BUY EXECUTED, Price: 31.90, Size: 650, Cost: 20735.00, Comm 20.73, RemSize: 0, RemCash: 47777.19
# 2014-01-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-01-31 00:00:00 cheat False
# 2014-01-31, LONG ORDER SENT, SPY, Price: 156.76, fast sma: 160.12, slow sma: 148.98, Size: 131.00
# 2014-01-31, LONG ORDER SENT, EFA, Price: 52.41, fast sma: 54.35, slow sma: 51.23, Size: 392.00
# 2014-01-31, FLAT ORDER SENT, TIP, Price: 101.12, fast sma: 100.29, slow sma: 101.56, Size: 0.00
# 2014-01-31, FLAT ORDER SENT, GSG, Price: 31.48, fast sma: 31.30, slow sma: 31.99, Size: 0.00
# 2014-01-31, FLAT ORDER SENT, VNQ, Price: 51.59, fast sma: 50.73, slow sma: 51.50, Size: 0.00
# 2014-02-03, BUY EXECUTED, Price: 156.57, Size: 3, Cost: 469.71, Comm 0.47, RemSize: 0, RemCash: 67008.87
# 2014-02-03, BUY EXECUTED, Price: 52.35, Size: 13, Cost: 680.55, Comm 0.68, RemSize: 0, RemCash: 67008.87
# 2014-02-03, SELL EXECUTED, Price: 31.39, Size: -650, Cost: 20735.00, Comm 20.40, RemSize: 0, RemCash: 67008.87
# 2014-02-03, OPERATION PROFIT, GROSS -331.50, NET -372.64
# 2014-02-28 23:59:59.999989 strategy notify_timer with tid 0, when 2014-02-28 00:00:00 cheat False
# 2014-02-28, LONG ORDER SENT, SPY, Price: 163.89, fast sma: 159.81, slow sma: 151.02, Size: 127.00
# 2014-02-28, LONG ORDER SENT, EFA, Price: 55.62, fast sma: 54.19, slow sma: 51.71, Size: 376.00
# 2014-02-28, LONG ORDER SENT, TIP, Price: 101.56, fast sma: 101.02, slow sma: 100.87, Size: 206.00
# 2014-02-28, LONG ORDER SENT, GSG, Price: 32.99, fast sma: 32.44, slow sma: 32.11, Size: 635.00
# 2014-02-28, LONG ORDER SENT, VNQ, Price: 54.20, fast sma: 52.77, slow sma: 51.24, Size: 386.00
# 2014-03-03, SELL EXECUTED, Price: 162.45, Size: -4, Cost: 453.42, Comm 0.65, RemSize: 0, RemCash: 5446.38
# 2014-03-03, SELL EXECUTED, Price: 54.69, Size: -16, Cost: 661.05, Comm 0.88, RemSize: 0, RemCash: 5446.38
# 2014-03-03, BUY EXECUTED, Price: 101.78, Size: 206, Cost: 20966.68, Comm 20.97, RemSize: 0, RemCash: 5446.38
# 2014-03-03, BUY EXECUTED, Price: 33.49, Size: 635, Cost: 21266.15, Comm 21.27, RemSize: 0, RemCash: 5446.38
# 2014-03-03, BUY EXECUTED, Price: 53.86, Size: 386, Cost: 20789.96, Comm 20.79, RemSize: 0, RemCash: 5446.38
# 2014-03-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-03-31 00:00:00 cheat False
# 2014-03-31, LONG ORDER SENT, SPY, Price: 165.25, fast sma: 164.44, slow sma: 153.29, Size: 126.00
# 2014-03-31, LONG ORDER SENT, EFA, Price: 55.36, fast sma: 54.68, slow sma: 52.31, Size: 377.00
# 2014-03-31, LONG ORDER SENT, TIP, Price: 101.02, fast sma: 101.16, slow sma: 100.51, Size: 206.00
# 2014-03-31, LONG ORDER SENT, GSG, Price: 32.97, fast sma: 32.76, slow sma: 32.26, Size: 634.00
# 2014-03-31, LONG ORDER SENT, VNQ, Price: 54.47, fast sma: 53.98, slow sma: 51.24, Size: 383.00
# 2014-04-01, SELL EXECUTED, Price: 165.79, Size: -1, Cost: 113.36, Comm 0.17, RemSize: 0, RemCash: 5752.62
# 2014-04-01, BUY EXECUTED, Price: 55.69, Size: 1, Cost: 55.69, Comm 0.06, RemSize: 0, RemCash: 5752.62
# 2014-04-01, SELL EXECUTED, Price: 32.82, Size: -1, Cost: 33.49, Comm 0.03, RemSize: 0, RemCash: 5752.62
# 2014-04-01, SELL EXECUTED, Price: 54.58, Size: -3, Cost: 161.58, Comm 0.16, RemSize: 0, RemCash: 5752.62
# 2014-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-04-30 00:00:00 cheat False
# 2014-04-30, LONG ORDER SENT, SPY, Price: 166.40, fast sma: 164.54, slow sma: 155.72, Size: 127.00
# 2014-04-30, LONG ORDER SENT, EFA, Price: 56.29, fast sma: 55.51, slow sma: 53.15, Size: 376.00
# 2014-04-30, LONG ORDER SENT, TIP, Price: 102.36, fast sma: 101.70, slow sma: 100.64, Size: 207.00
# 2014-04-30, LONG ORDER SENT, GSG, Price: 33.30, fast sma: 33.25, slow sma: 32.43, Size: 637.00
# 2014-04-30, LONG ORDER SENT, VNQ, Price: 56.26, fast sma: 55.33, slow sma: 51.64, Size: 377.00
# 2014-05-01, BUY EXECUTED, Price: 166.32, Size: 1, Cost: 166.32, Comm 0.17, RemSize: 0, RemCash: 5778.42
# 2014-05-01, SELL EXECUTED, Price: 56.34, Size: -1, Cost: 41.35, Comm 0.06, RemSize: 0, RemCash: 5778.42
# 2014-05-01, BUY EXECUTED, Price: 102.44, Size: 1, Cost: 102.44, Comm 0.10, RemSize: 0, RemCash: 5778.42
# 2014-05-01, BUY EXECUTED, Price: 33.04, Size: 3, Cost: 99.12, Comm 0.10, RemSize: 0, RemCash: 5778.42
# 2014-05-01, SELL EXECUTED, Price: 56.35, Size: -6, Cost: 323.16, Comm 0.34, RemSize: 0, RemCash: 5778.42
# 2014-05-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-05-30 00:00:00 cheat False
# 2014-05-30, LONG ORDER SENT, SPY, Price: 170.26, fast sma: 167.20, slow sma: 157.80, Size: 126.00
# 2014-05-30, LONG ORDER SENT, EFA, Price: 57.19, fast sma: 56.51, slow sma: 53.85, Size: 376.00
# 2014-05-30, LONG ORDER SENT, TIP, Price: 104.40, fast sma: 103.53, slow sma: 100.88, Size: 206.00
# 2014-05-30, LONG ORDER SENT, GSG, Price: 33.13, fast sma: 33.32, slow sma: 32.50, Size: 649.00
# 2014-05-30, LONG ORDER SENT, VNQ, Price: 57.61, fast sma: 57.10, slow sma: 52.13, Size: 373.00
# 2014-06-02, SELL EXECUTED, Price: 170.50, Size: -1, Cost: 113.77, Comm 0.17, RemSize: 0, RemCash: 5887.39
# 2014-06-02, SELL EXECUTED, Price: 104.26, Size: -1, Cost: 101.78, Comm 0.10, RemSize: 0, RemCash: 5887.39
# 2014-06-02, BUY EXECUTED, Price: 33.00, Size: 12, Cost: 396.00, Comm 0.40, RemSize: 0, RemCash: 5887.39
# 2014-06-02, SELL EXECUTED, Price: 57.78, Size: -4, Cost: 215.44, Comm 0.23, RemSize: 0, RemCash: 5887.39
# 2014-06-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-06-30 00:00:00 cheat False
# 2014-06-30, LONG ORDER SENT, SPY, Price: 173.77, fast sma: 172.62, slow sma: 160.73, Size: 125.00
# 2014-06-30, LONG ORDER SENT, EFA, Price: 57.71, fast sma: 57.63, slow sma: 54.65, Size: 378.00
# 2014-06-30, LONG ORDER SENT, TIP, Price: 104.79, fast sma: 103.80, slow sma: 101.38, Size: 208.00
# 2014-06-30, LONG ORDER SENT, GSG, Price: 33.92, fast sma: 33.74, slow sma: 32.53, Size: 643.00
# 2014-06-30, LONG ORDER SENT, VNQ, Price: 58.26, fast sma: 57.90, slow sma: 53.09, Size: 374.00
# 2014-07-01, SELL EXECUTED, Price: 174.20, Size: -1, Cost: 113.77, Comm 0.17, RemSize: 0, RemCash: 5880.67
# 2014-07-01, BUY EXECUTED, Price: 58.01, Size: 2, Cost: 116.02, Comm 0.12, RemSize: 0, RemCash: 5880.67
# 2014-07-01, BUY EXECUTED, Price: 104.56, Size: 2, Cost: 209.12, Comm 0.21, RemSize: 0, RemCash: 5880.67
# 2014-07-01, SELL EXECUTED, Price: 33.88, Size: -6, Cost: 200.87, Comm 0.20, RemSize: 0, RemCash: 5880.67
# 2014-07-01, BUY EXECUTED, Price: 58.30, Size: 1, Cost: 58.30, Comm 0.06, RemSize: 0, RemCash: 5880.67
# 2014-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-07-31 00:00:00 cheat False
# 2014-07-31, LONG ORDER SENT, SPY, Price: 171.44, fast sma: 175.07, slow sma: 163.70, Size: 124.00
# 2014-07-31, LONG ORDER SENT, EFA, Price: 56.21, fast sma: 57.32, slow sma: 55.22, Size: 381.00
# 2014-07-31, LONG ORDER SENT, TIP, Price: 104.69, fast sma: 104.87, slow sma: 101.83, Size: 204.00
# 2014-07-31, LONG ORDER SENT, GSG, Price: 32.00, fast sma: 32.66, slow sma: 32.54, Size: 669.00
# 2014-07-31, LONG ORDER SENT, VNQ, Price: 58.31, fast sma: 59.05, slow sma: 54.03, Size: 367.00
# 2014-08-01, SELL EXECUTED, Price: 170.97, Size: -1, Cost: 113.77, Comm 0.17, RemSize: 0, RemCash: 5882.61
# 2014-08-01, BUY EXECUTED, Price: 55.98, Size: 3, Cost: 167.94, Comm 0.17, RemSize: 0, RemCash: 5882.61
# 2014-08-01, SELL EXECUTED, Price: 104.90, Size: -4, Cost: 407.24, Comm 0.42, RemSize: 0, RemCash: 5882.61
# 2014-08-01, BUY EXECUTED, Price: 31.80, Size: 26, Cost: 826.80, Comm 0.83, RemSize: 0, RemCash: 5882.61
# 2014-08-01, SELL EXECUTED, Price: 58.30, Size: -7, Cost: 377.10, Comm 0.41, RemSize: 0, RemCash: 5882.61
# 2014-08-29 23:59:59.999989 strategy notify_timer with tid 0, when 2014-08-29 00:00:00 cheat False
# 2014-08-29, LONG ORDER SENT, SPY, Price: 178.21, fast sma: 174.51, slow sma: 165.89, Size: 121.00
# 2014-08-29, LONG ORDER SENT, EFA, Price: 56.31, fast sma: 55.89, slow sma: 55.45, Size: 384.00
# 2014-08-29, LONG ORDER SENT, TIP, Price: 105.33, fast sma: 105.25, slow sma: 102.25, Size: 205.00
# 2014-08-29, FLAT ORDER SENT, GSG, Price: 31.50, fast sma: 31.33, slow sma: 32.49, Size: 0.00
# 2014-08-29, LONG ORDER SENT, VNQ, Price: 60.08, fast sma: 59.27, slow sma: 54.78, Size: 360.00
# 2014-09-02, SELL EXECUTED, Price: 178.44, Size: -3, Cost: 341.32, Comm 0.54, RemSize: 0, RemCash: 27374.02
# 2014-09-02, BUY EXECUTED, Price: 56.48, Size: 3, Cost: 169.44, Comm 0.17, RemSize: 0, RemCash: 27374.02
# 2014-09-02, BUY EXECUTED, Price: 104.93, Size: 1, Cost: 104.93, Comm 0.10, RemSize: 0, RemCash: 27374.02
# 2014-09-02, SELL EXECUTED, Price: 31.14, Size: -669, Cost: 22353.71, Comm 20.83, RemSize: 0, RemCash: 27374.02
# 2014-09-02, SELL EXECUTED, Price: 59.98, Size: -7, Cost: 377.10, Comm 0.42, RemSize: 0, RemCash: 27374.02
# 2014-09-02, OPERATION PROFIT, GROSS -1519.31, NET -1562.97
# 2014-09-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-09-30 00:00:00 cheat False
# 2014-09-30, LONG ORDER SENT, SPY, Price: 175.75, fast sma: 177.44, slow sma: 168.00, Size: 119.00
# 2014-09-30, FLAT ORDER SENT, EFA, Price: 54.12, fast sma: 55.54, slow sma: 55.67, Size: 0.00
# 2014-09-30, LONG ORDER SENT, TIP, Price: 102.60, fast sma: 103.27, slow sma: 102.58, Size: 205.00
# ...
# 2019-06-28, FLAT ORDER SENT, GSG, Price: 15.65, fast sma: 15.23, slow sma: 16.00, Size: 0.00
# 2019-06-28, LONG ORDER SENT, VNQ, Price: 84.29, fast sma: 85.10, slow sma: 78.50, Size: 272.00
# 2019-07-01, SELL EXECUTED, Price: 290.87, Size: -3, Cost: 816.98, Comm 0.87, RemSize: 0, RemCash: 29343.97
# 2019-07-01, SELL EXECUTED, Price: 64.73, Size: -10, Cost: 624.70, Comm 0.65, RemSize: 0, RemCash: 29343.97
# 2019-07-01, BUY EXECUTED, Price: 113.66, Size: 5, Cost: 568.30, Comm 0.57, RemSize: 0, RemCash: 29343.97
# 2019-07-01, BUY EXECUTED, Price: 84.85, Size: 4, Cost: 339.40, Comm 0.34, RemSize: 0, RemCash: 29343.97
# 2019-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-07-31 00:00:00 cheat False
# 2019-07-31, LONG ORDER SENT, SPY, Price: 291.61, fast sma: 293.40, slow sma: 270.97, Size: 78.00
# 2019-07-31, LONG ORDER SENT, EFA, Price: 62.84, fast sma: 64.01, slow sma: 60.91, Size: 366.00
# 2019-07-31, LONG ORDER SENT, TIP, Price: 113.92, fast sma: 113.70, slow sma: 109.38, Size: 202.00
# 2019-07-31, FLAT ORDER SENT, GSG, Price: 15.58, fast sma: 15.65, slow sma: 15.74, Size: 0.00
# 2019-07-31, LONG ORDER SENT, VNQ, Price: 85.72, fast sma: 85.84, slow sma: 79.67, Size: 268.00
# 2019-08-01, SELL EXECUTED, Price: 291.78, Size: -1, Cost: 272.33, Comm 0.29, RemSize: 0, RemCash: 29474.62
# 2019-08-01, BUY EXECUTED, Price: 62.92, Size: 8, Cost: 503.36, Comm 0.50, RemSize: 0, RemCash: 29474.62
# 2019-08-01, SELL EXECUTED, Price: 85.84, Size: -4, Cost: 300.77, Comm 0.34, RemSize: 0, RemCash: 29474.62
# 2019-08-30 23:59:59.999989 strategy notify_timer with tid 0, when 2019-08-30 00:00:00 cheat False
# 2019-08-30, LONG ORDER SENT, SPY, Price: 286.73, fast sma: 283.53, slow sma: 273.13, Size: 80.00
# 2019-08-30, FLAT ORDER SENT, EFA, Price: 61.63, fast sma: 60.96, slow sma: 61.08, Size: 0.00
# 2019-08-30, LONG ORDER SENT, TIP, Price: 116.57, fast sma: 115.97, slow sma: 110.44, Size: 198.00
# 2019-08-30, FLAT ORDER SENT, GSG, Price: 14.82, fast sma: 14.79, slow sma: 15.48, Size: 0.00
# 2019-08-30, LONG ORDER SENT, VNQ, Price: 88.93, fast sma: 87.52, slow sma: 81.20, Size: 260.00
# 2019-09-03, BUY EXECUTED, Price: 284.88, Size: 2, Cost: 569.76, Comm 0.57, RemSize: 0, RemCash: 52486.40
# 2019-09-03, SELL EXECUTED, Price: 61.28, Size: -366, Cost: 22867.80, Comm 22.43, RemSize: 0, RemCash: 52486.40
# 2019-09-03, SELL EXECUTED, Price: 116.49, Size: -4, Cost: 434.56, Comm 0.47, RemSize: 0, RemCash: 52486.40
# 2019-09-03, SELL EXECUTED, Price: 88.91, Size: -8, Cost: 601.53, Comm 0.71, RemSize: 0, RemCash: 52486.40
# 2019-09-03, OPERATION PROFIT, GROSS -408.86, NET -456.19
# 2019-09-30 23:59:59.999989 strategy notify_timer with tid 0, when 2019-09-30 00:00:00 cheat False
# 2019-09-30, LONG ORDER SENT, SPY, Price: 292.31, fast sma: 292.74, slow sma: 276.39, Size: 79.00
# 2019-09-30, LONG ORDER SENT, EFA, Price: 63.58, fast sma: 63.41, slow sma: 61.55, Size: 365.00
# 2019-09-30, LONG ORDER SENT, TIP, Price: 115.28, fast sma: 115.38, slow sma: 111.34, Size: 201.00
# 2019-09-30, FLAT ORDER SENT, GSG, Price: 15.05, fast sma: 15.29, slow sma: 15.46, Size: 0.00
# 2019-09-30, LONG ORDER SENT, VNQ, Price: 90.65, fast sma: 89.87, slow sma: 82.59, Size: 256.00
# 2019-10-01, SELL EXECUTED, Price: 293.26, Size: -1, Cost: 272.64, Comm 0.29, RemSize: 0, RemCash: 29632.43
# 2019-10-01, BUY EXECUTED, Price: 63.40, Size: 365, Cost: 23141.00, Comm 23.14, RemSize: 0, RemCash: 29632.43
# 2019-10-01, BUY EXECUTED, Price: 114.83, Size: 3, Cost: 344.49, Comm 0.34, RemSize: 0, RemCash: 29632.43
# 2019-10-01, SELL EXECUTED, Price: 90.60, Size: -4, Cost: 300.77, Comm 0.36, RemSize: 0, RemCash: 29632.43
# 2019-10-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-10-31 00:00:00 cheat False
# 2019-10-31, LONG ORDER SENT, SPY, Price: 298.77, fast sma: 293.62, slow sma: 281.84, Size: 78.00
# 2019-10-31, LONG ORDER SENT, EFA, Price: 65.74, fast sma: 64.31, slow sma: 62.38, Size: 357.00
# 2019-10-31, LONG ORDER SENT, TIP, Price: 115.25, fast sma: 115.16, slow sma: 112.27, Size: 204.00
# 2019-10-31, FLAT ORDER SENT, GSG, Price: 15.17, fast sma: 15.17, slow sma: 15.53, Size: 0.00
# 2019-10-31, LONG ORDER SENT, VNQ, Price: 91.67, fast sma: 91.24, slow sma: 84.77, Size: 256.00
# 2019-11-01, SELL EXECUTED, Price: 300.33, Size: -1, Cost: 272.64, Comm 0.30, RemSize: 0, RemCash: 30114.96
# 2019-11-01, SELL EXECUTED, Price: 66.16, Size: -8, Cost: 507.20, Comm 0.53, RemSize: 0, RemCash: 30114.96
# 2019-11-01, BUY EXECUTED, Price: 115.30, Size: 3, Cost: 345.90, Comm 0.35, RemSize: 0, RemCash: 30114.96
# 2019-11-29 23:59:59.999989 strategy notify_timer with tid 0, when 2019-11-29 00:00:00 cheat False
# 2019-11-29, LONG ORDER SENT, SPY, Price: 309.58, fast sma: 305.62, slow sma: 286.31, Size: 76.00
# 2019-11-29, LONG ORDER SENT, EFA, Price: 66.48, fast sma: 66.53, slow sma: 63.09, Size: 356.00
# 2019-11-29, LONG ORDER SENT, TIP, Price: 115.59, fast sma: 115.36, slow sma: 113.03, Size: 205.00
# 2019-11-29, FLAT ORDER SENT, GSG, Price: 15.23, fast sma: 15.54, slow sma: 15.56, Size: 0.00
# 2019-11-29, LONG ORDER SENT, VNQ, Price: 90.47, fast sma: 89.78, slow sma: 85.95, Size: 261.00
# 2019-12-02, SELL EXECUTED, Price: 309.86, Size: -2, Cost: 545.28, Comm 0.62, RemSize: 0, RemCash: 30234.11
# 2019-12-02, SELL EXECUTED, Price: 66.40, Size: -1, Cost: 63.40, Comm 0.07, RemSize: 0, RemCash: 30234.11
# 2019-12-02, BUY EXECUTED, Price: 115.17, Size: 1, Cost: 115.17, Comm 0.12, RemSize: 0, RemCash: 30234.11
# 2019-12-02, BUY EXECUTED, Price: 90.11, Size: 5, Cost: 450.55, Comm 0.45, RemSize: 0, RemCash: 30234.11
# <backtrader.metabase.ItemCollection object at 0x0000022383E0B488>
# 2019-12-30, ROI:        26.08%
# 2019-12-30, (Mebane Faber TAA Ending Value 126076.58
# Final Portfolio Value: 126076.58, Sharpe Ratio: 0.33, DrawDown: 0.23, MoneyDown 287.95
# <img src="data:image/png;base64,..." width="432">
# -------------- RETURNS ----------------
# index
# 2010-01-04 00:00:00+00:00    0.000000
# 2010-01-05 00:00:00+00:00    0.000000
# 2010-01-06 00:00:00+00:00    0.000000
# 2010-01-07 00:00:00+00:00    0.000000
# 2010-01-08 00:00:00+00:00    0.000000
#                                ...
# 2019-12-23 00:00:00+00:00   -0.000658
# 2019-12-24 00:00:00+00:00    0.000513
# 2019-12-26 00:00:00+00:00    0.002834
# 2019-12-27 00:00:00+00:00    0.000934
# 2019-12-30 00:00:00+00:00   -0.002279
# Name: return, Length: 2515, dtype: float64
# -------------- POSITIONS ----------------
#                  SPY       EFA       TIP  GSG       VNQ          cash
# 2010-01-04      0.00      0.00      0.00  0.0      0.00  100000.00000
# 2010-01-05      0.00      0.00      0.00  0.0      0.00  100000.00000
# 2010-01-06      0.00      0.00      0.00  0.0      0.00  100000.00000
# 2010-01-07      0.00      0.00      0.00  0.0      0.00  100000.00000
# 2010-01-08      0.00      0.00      0.00  0.0      0.00  100000.00000
# ...              ...       ...       ...  ...       ...           ...
# 2019-12-23  24163.44  24321.92  23741.05  0.0  23364.72   30234.11205
# 2019-12-24  24164.20  24297.00  23769.75  0.0  23424.75   30234.11205
# 2019-12-26  24293.40  24403.80  23786.15  0.0  23529.15   30234.11205
# 2019-12-27  24287.32  24446.52  23794.35  0.0  23602.23   30234.11205
# 2019-12-30  24152.80  24261.40  23802.55  0.0  23625.72   30234.11205
#
# [2515 rows x 6 columns]
# -------------- TRANSACTIONS ----------------
#                                   amount   price  sid symbol     value
# date
# 2010-11-01 23:59:59.999989+00:00     195   97.87    0    SPY -19084.65
# 2010-11-01 23:59:59.999989+00:00     448   42.43    1    EFA -19008.64
# 2010-11-01 23:59:59.999989+00:00     205   92.98    2    TIP -19060.90
# 2010-11-01 23:59:59.999989+00:00     615   31.42    3    GSG -19323.30
# 2010-11-01 23:59:59.999989+00:00     515   37.05    4    VNQ -19080.75
# ...                                  ...     ...  ...    ...       ...
# 2019-11-01 23:59:59.999989+00:00       3  115.30    2    TIP   -345.90
# 2012  0.010  0.017
# 2013  0.004  0.009
# 2014  0.009  0.001
# 2015 -0.002 -0.001
# 2016  0.003  0.007
# 2017  0.015  0.014
# 2018 -0.009 -0.008
# 2019  0.007  0.011
# -------------- ANNUAL RETURN ----------------
# return  2010    0.035
#         2011    0.019
#         2012   -0.005
#         2013    0.056
#         2014    0.039
#         2015   -0.044
#         2016   -0.001
#         2017    0.093
#         2018   -0.032
#         2019    0.089
# dtype: float64
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-11-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>109</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>2.6%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>26.6%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>7.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.40</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.71</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.6%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.53</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.93</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>13.29</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.9%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.66</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>1.4%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.55</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13.58</td>
#       <td>2011-05-02</td>
#       <td>2011-08-08</td>
#       <td>2014-05-12</td>
#       <td>791</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.99</td>
#       <td>2015-04-28</td>
#       <td>2016-01-20</td>
#       <td>2017-11-02</td>
#       <td>658</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.58</td>
#       <td>2018-01-26</td>
#       <td>2018-12-24</td>
#       <td>2019-10-21</td>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.08</td>
#       <td>2010-11-05</td>
#       <td>2010-11-16</td>
#       <td>2010-12-29</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.72</td>
#       <td>2011-03-03</td>
#       <td>2011-03-16</td>
#       <td>2011-04-01</td>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.04%</td>
#       <td>-0.76%</td>
#       <td>1.07%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.08%</td>
#       <td>-0.87%</td>
#       <td>0.61%</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TIP</th>
#       <td>21.69%</td>
#     </tr>
#     <tr>
#       <th>VNQ</th>
#       <td>20.78%</td>
#     </tr>
#     <tr>
#       <th>GSG</th>
#       <td>20.38%</td>
#     </tr>
#     <tr>
#       <th>EFA</th>
#       <td>20.28%</td>
#     </tr>
#     <tr>
#       <th>SPY</th>
#       <td>20.05%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TIP</th>
#       <td>21.69%</td>
#     </tr>
#     <tr>
#       <th>VNQ</th>
#       <td>20.78%</td>
#     </tr>
#     <tr>
#       <th>GSG</th>
#       <td>20.38%</td>
#     </tr>
#     <tr>
#       <th>EFA</th>
#       <td>20.28%</td>
#     </tr>
#     <tr>
#       <th>SPY</th>
#       <td>20.05%</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
# d:\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="432">
