# %%
'''
This is a follow up of https://letianzj.github.io/portfolio-management-one.html
It backtests four portfolios: GMV, tangent, maximum diversification and risk parity
and compare them with equally-weighted portfolio
'''
import os
import numpy as np
import pandas as pd
from datetime import datetime
import backtrader as bt
from scipy.optimize import minimize
from IPython.core.display import display, HTML
# set browser full width
display(HTML("<style>.container { width:100% !important; }</style>"))


class EndOfMonth(object):
    def __init__(self, cal):
        self.cal = cal

    def __call__(self, d):
        if self.cal.last_monthday(d):
            return True
        return False

# ------------------ help functions -------------------------------- #
def minimum_vol_obj(wo, cov):
    w = wo.reshape(-1, 1)
    sig_p = np.sqrt(np.matmul(w.T, np.matmul(cov, w)))[0, 0]    # portfolio sigma
    return sig_p

def maximum_sharpe_negative_obj(wo, mu_cov):
    w = wo.reshape(-1, 1)
    mu = mu_cov[0].reshape(-1, 1)
    cov = mu_cov[1]
    obj = np.matmul(w.T, mu)[0, 0]
    sig_p = np.sqrt(np.matmul(w.T, np.matmul(cov, w)))[0, 0]    # portfolio sigma
    obj = -1 * obj/sig_p
    return obj

def maximum_diversification_negative_obj(wo, cov):
    w = wo.reshape(-1, 1)
    w_vol = np.matmul(w.T, np.sqrt(np.diag(cov).reshape(-1, 1)))[0, 0]
    port_vol = np.sqrt(np.matmul(w.T, np.matmul(cov, w)))[0, 0]
    ratio = w_vol / port_vol
    return -ratio

# this is also used to verify rc from optimal w
def calc_risk_contribution(wo, cov):
    w = wo.reshape(-1, 1)
    sigma = np.sqrt(np.matmul(w.T, np.matmul(cov, w)))[0, 0]
    mrc = np.matmul(cov, w)
    rc = (w * mrc) / sigma  # element-wise multiplication
    return rc

def risk_budget_obj(wo, cov_wb):
    w = wo.reshape(-1, 1)
    cov = cov_wb[0]
    wb = cov_wb[1].reshape(-1, 1)  # target/budget in percent of portfolio risk
    sig_p = np.sqrt(np.matmul(w.T, np.matmul(cov, w)))[0, 0]  # portfolio sigma
    risk_target = sig_p * wb
    asset_rc = calc_risk_contribution(w, cov)
    f = np.sum(np.square(asset_rc - risk_target.T))  # sum of squared error
    return f

class PortfolioOptimization(bt.Strategy):
    params = (
        ('nlookback', 200),
        ('model', 'gmv'),         # gmv, sharpe, diversified, risk_parity
        ('printlog', False),        # comma is required
    )

    def __init__(self):
        self.buyprice = None
        self.buycomm = None
        self.bar_executed = None
        self.val_start = None

        self.add_timer(
            when=bt.Timer.SESSION_START,       # before next
            allow=EndOfMonth(cal = bt.TradingCalendar())
        )

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function fot this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash
        print(f'================================== start portfolio {self.p.model} ======================================')

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' % (trade.pnl, trade.pnlcomm))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:                # order.Partial
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                    (order.executed.price,
                     order.executed.size,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.remsize,
                     self.broker.get_cash()))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                         (order.executed.price,
                          order.executed.size,
                          order.executed.value,
                          order.executed.comm,
                          order.executed.remsize,
                          self.broker.get_cash()))

            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Expired, order.Margin, order.Rejected]:
            self.log('Order Failed')

    def next(self):
        pass

    def notify_timer(self, timer, when, *args, **kwargs):
        print('{} strategy notify_timer with tid {}, when {} cheat {}'.
              format(self.data.datetime.datetime(), timer.p.tid, when, timer.p.cheat))
        if len(self.datas[0]) < self.p.nlookback:       # not enough bars
            return

        total_value = self.broker.getvalue()
        i = 0
        prices = None
        for data in self.datas:
            price = data.close.get(0, self.p.nlookback)
            price = np.array(price)
            if i == 0:
                prices = price
            else:
                prices = np.c_[prices, price]
            i += 1
        rets = prices[1:,:]/prices[0:-1, :]-1.0
        mu = np.mean(rets, axis=0)
        cov = np.cov(rets.T)

        n_stocks = len(self.datas)
        TOL = 1e-12
        w = np.ones(n_stocks) / n_stocks      # default
        try:
            if self.p.model == 'gmv':
                w0 = np.ones(n_stocks) / n_stocks
                cons = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1.0}, {'type': 'ineq', 'fun': lambda w: w})
                res = minimize(minimum_vol_obj, w0, args=cov, method='SLSQP', constraints=cons, tol=TOL, options={'disp': True})
                if not res.success:
                    self.log(f'{self.p.model} Optimization failed')
                w = res.x
            elif self.p.model == 'sharpe':
                w0 = np.ones(n_stocks) / n_stocks
                cons = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1.0}, {'type': 'ineq', 'fun': lambda w: w})
                res = minimize(maximum_sharpe_negative_obj, w0, args=[mu, cov], method='SLSQP', constraints=cons, tol=TOL, options={'disp': True})
                w = res.x
            elif self.p.model == 'diversified':
                w0 = np.ones(n_stocks) / n_stocks
                cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1.0})  # weights sum to one
                bnds = tuple([(0, 1)] * n_stocks)
                res = minimize(maximum_diversification_negative_obj, w0, bounds=bnds, args=cov, method='SLSQP', constraints=cons, tol=TOL, options={'disp': True})
                w = res.x
            elif self.p.model == 'risk_parity':
                w0 = np.ones(n_stocks) / n_stocks
                w_b = np.ones(n_stocks) / n_stocks  # risk budget/target, percent of total portfolio risk (in this case equal risk)
                # bnds = ((0,1),(0,1),(0,1),(0,1)) # alternative, use bounds for weights, one for each stock
                cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1.0}, {'type': 'ineq', 'fun': lambda x: x})
                res = minimize(risk_budget_obj, w0, args=[cov, w_b], method='SLSQP', constraints=cons, tol=TOL, options={'disp': True})
                w = res.x
        except Exception as e:
            self.log(f'{self.p.model} Optimization failed; {str(e)}')

        stock_value = total_value * 0.95
        i = 0
        for data in self.datas:
            target_pos = (int)(stock_value * w[i] / data.close[0])
            self.order_target_size(data=data, target=target_pos)
            self.log('REBALANCE ORDER SENT, %s, Price: %.2f, Percentage: %.2f, Target Size: %.2f' %
                         (data._name,
                          data.close[0],
                          w[i],
                          target_pos))
            i += 1

    def stop(self):
        # calculate the actual returns
        print(self.analyzers)
        roi = (self.broker.get_value() / self.val_start) - 1.0
        self.log('ROI:        {:.2f}%'.format(100.0 * roi))
        self.log(f'{self.p.model} ending Value {self.broker.getvalue():.2f}', doprint=True)


if __name__ == '__main__':
    param_opt = False
    perf_eval = True
    initial_capital = 100000.0
    etfs = ['SPY', 'EFA', 'TIP', 'GSG', 'VNQ']
    benchmark = etfs

    strategies = ['gmv', 'sharpe', 'diversified', 'risk_parity']
    dict_results = dict()
    for sname in strategies:
        dict_results[sname] = dict()
        cerebro = bt.Cerebro()

        # Add the Data Feed to Cerebro
        # SPY: S&P 500
        # EFA: MSCI EAFE
        # TIP: UST
        # GSG: GSCI
        # VNQ: REITs
        for s in etfs:
            # Create a Data Feed
            data = bt.feeds.YahooFinanceCSVData(
                dataname=os.path.join('../data/', f'{s}.csv'),
                fromdate=datetime(2010, 1, 1),
                todate=datetime(2019, 12, 31),
                reverse=False)
            cerebro.adddata(data, name=s)

        # Set our desired cash start
        cerebro.broker.setcash(initial_capital)

        # Set the commission - 0.1% ... divide by 100 to remove the %
        cerebro.broker.setcommission(commission=0.001)

        # Print out the starting conditions
        print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

        # Add a strategy
        cerebro.addstrategy(PortfolioOptimization, model=sname, printlog=True)

        # Add Analyzer
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='SharpeRatio')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DrawDown')
        cerebro.addanalyzer(bt.analyzers.PositionsValue, _name='positions', cash=True)
        cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

        # Run over everything
        results = cerebro.run()

        # Print out the final result
        strat = results[0]
        print('Final Portfolio Value: %.2f, Sharpe Ratio: %.2f, DrawDown: %.2f, MoneyDown %.2f' %
              (cerebro.broker.getvalue(),
               strat.analyzers.SharpeRatio.get_analysis()['sharperatio'],
               strat.analyzers.DrawDown.get_analysis()['drawdown'],
               strat.analyzers.DrawDown.get_analysis()['moneydown']))

        pyfoliozer = strat.analyzers.getbyname('pyfolio')
        returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
        # somehow pyfolio analyzer doesn't handle well multi-assets
        df_positions = pd.DataFrame.from_dict(strat.analyzers.positions.get_analysis(), orient='index')
        df_positions.columns = etfs+['cash']
        returns = returns[transactions.index[0]:]  # count from first trade
        # returns.index = returns.index.tz_localize(None)  # # remove tzinfo; tz native
        df_positions.index = df_positions.index.map(lambda x: datetime.combine(x, datetime.min.time()))
        df_positions.index = df_positions.index.tz_localize('UTC')
        df_positions = df_positions.loc[returns.index]

        # save immediate results
        dict_results[sname]['returns'] = returns
        dict_results[sname]['positions'] = df_positions
        dict_results[sname]['transactions'] = transactions

    # Compare four portfolios with equal weighted
    import matplotlib.pyplot as plt
    import empyrical as ep
    import pyfolio as pf

    bm_ret = None
    df_constituents = pd.DataFrame()
    for s in etfs:
        datapath = os.path.join('../data/', f'{s}.csv')
        df_temp = pd.read_csv(datapath, index_col=0)
        df_temp = df_temp['Adj Close']
        df_temp.name = s
        df_constituents = pd.concat([df_constituents, df_temp], axis=1)

    df_constituents_ret = df_constituents.pct_change()
    df_constituents_ret.index = pd.to_datetime(df_constituents_ret.index)
    df_constituents_ret.index = df_constituents_ret.index.tz_localize('UTC')
    df_constituents_ret = df_constituents_ret.loc[returns.index]
    df_constituents_ret['Benchmark'] = df_constituents_ret.mean(axis=1)  # 20% each
    df_constituents_value = initial_capital * (df_constituents_ret + 1).cumprod()

    # return stats
    perf_stats_all = pd.DataFrame()
    for s in strategies:
        perf_stats_strat = pf.timeseries.perf_stats(dict_results[s]['returns'])
        perf_stats_strat.name = s
        perf_stats_all = pd.concat([perf_stats_all, perf_stats_strat], axis=1)
    perf_stats_bm = pf.timeseries.perf_stats(df_constituents_ret.Benchmark)
    perf_stats_bm.name = 'equal_weights'
    perf_stats_all = pd.concat([perf_stats_all, perf_stats_bm], axis=1)
    print(perf_stats_all)

    # portfolio values
    portfolio_value_all = pd.DataFrame()
    for s in strategies:
        port_value = dict_results[s]['positions'].sum(axis=1)
        port_value.name = s
        portfolio_value_all = pd.concat([portfolio_value_all, port_value], axis=1)
    port_value = df_constituents_value.Benchmark.copy()
    port_value.name = 'equal_weights'
    portfolio_value_all = pd.concat([portfolio_value_all, port_value], axis=1)
    fig, ax = plt.subplots(2, 1, figsize=(5, 12))
    portfolio_value_all.plot(ax=ax[0])
    df_constituents_value[etfs].plot(ax=ax[1])
    fig.tight_layout()
    plt.show()

    # monthly returns
    fig, ax = plt.subplots(5, 1, figsize=(10, 35))
    i = 0
    for s in strategies:
        pf.plotting.plot_monthly_returns_heatmap(dict_results[s]['returns'], ax[i])
        ax[i].title.set_text(s)
        i += 1
    pf.plotting.plot_monthly_returns_heatmap(df_constituents_ret['Benchmark'], ax[i])
    ax[i].title.set_text('equal weighted')
    fig.tight_layout()
    plt.show()

    # positions
    fig, ax = plt.subplots(4, 1, figsize=(25, 25))
    i = 0
    for s in strategies:
        sum_ = dict_results[s]['positions'].sum(axis=1)
        pcts = []
        for etf in etfs:
            pct = dict_results[s]['positions'][etf] / sum_
            pcts.append(pct)
        ax[i].stackplot(dict_results[s]['positions'].index, pcts, labels=etfs)
        ax[i].legend(loc='upper left')
        ax[i].title.set_text(s)
        i += 1
    fig.tight_layout()
    plt.show()
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003471058421130262
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2011-12-30, REBALANCE ORDER SENT, SPY, Price: 105.88, Percentage: 0.16, Target Size: 156.00
# 2011-12-30, REBALANCE ORDER SENT, EFA, Price: 38.33, Percentage: -0.00, Target Size: 0.00
# 2011-12-30, REBALANCE ORDER SENT, TIP, Price: 101.72, Percentage: 0.84, Target Size: 834.00
# 2011-12-30, REBALANCE ORDER SENT, GSG, Price: 32.98, Percentage: 0.00, Target Size: 0.00
# 2011-12-30, REBALANCE ORDER SENT, VNQ, Price: 41.11, Percentage: -0.00, Target Size: 0.00
# 2012-01-03, SELL EXECUTED, Price: 107.78, Size: -6, Cost: 624.15, Comm 0.65, RemSize: 0, RemCash: 5469.79
# 2012-01-03, BUY EXECUTED, Price: 101.50, Size: 6, Cost: 609.00, Comm 0.61, RemSize: 0, RemCash: 5469.79
# 2012-01-31 23:59:59.999989 strategy notify_timer with tid 0, when 2012-01-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0034514149931247646
#             Iterations: 17
#             Function evaluations: 119
#             Gradient evaluations: 17
# 2012-01-31, REBALANCE ORDER SENT, SPY, Price: 110.79, Percentage: 0.16, Target Size: 152.00
# 2012-01-31, REBALANCE ORDER SENT, EFA, Price: 40.35, Percentage: -0.00, Target Size: 0.00
# 2012-01-31, REBALANCE ORDER SENT, TIP, Price: 104.05, Percentage: 0.84, Target Size: 837.00
# 2012-01-31, REBALANCE ORDER SENT, GSG, Price: 33.77, Percentage: 0.00, Target Size: 0.00
# 2012-01-31, REBALANCE ORDER SENT, VNQ, Price: 43.73, Percentage: 0.00, Target Size: 0.00
# 2012-02-01, SELL EXECUTED, Price: 111.60, Size: -4, Cost: 416.10, Comm 0.45, RemSize: 0, RemCash: 5603.76
# 2012-02-01, BUY EXECUTED, Price: 103.89, Size: 3, Cost: 311.67, Comm 0.31, RemSize: 0, RemCash: 5603.76
# 2012-02-29 23:59:59.999989 strategy notify_timer with tid 0, when 2012-02-29 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0034676478850605473
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2012-02-29, REBALANCE ORDER SENT, SPY, Price: 115.60, Percentage: 0.17, Target Size: 150.00
# 2012-02-29, REBALANCE ORDER SENT, EFA, Price: 42.30, Percentage: -0.00, Target Size: 0.00
# 2012-02-29, REBALANCE ORDER SENT, TIP, Price: 103.45, Percentage: 0.83, Target Size: 839.00
# 2012-02-29, REBALANCE ORDER SENT, GSG, Price: 35.87, Percentage: 0.00, Target Size: 0.00
# 2012-02-29, REBALANCE ORDER SENT, VNQ, Price: 43.23, Percentage: 0.00, Target Size: 0.00
# 2012-03-01, SELL EXECUTED, Price: 115.84, Size: -2, Cost: 208.05, Comm 0.23, RemSize: 0, RemCash: 5628.71
# 2012-03-01, BUY EXECUTED, Price: 103.15, Size: 2, Cost: 206.30, Comm 0.21, RemSize: 0, RemCash: 5628.71
# 2012-03-30 23:59:59.999989 strategy notify_timer with tid 0, when 2012-03-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0035189028976602044
#             Iterations: 20
#             Function evaluations: 140
#             Gradient evaluations: 20
# 2012-03-30, REBALANCE ORDER SENT, SPY, Price: 119.31, Percentage: 0.17, Target Size: 146.00
# 2012-03-30, REBALANCE ORDER SENT, EFA, Price: 42.48, Percentage: -0.00, Target Size: 0.00
# 2012-03-30, REBALANCE ORDER SENT, TIP, Price: 102.56, Percentage: 0.83, Target Size: 844.00
# 2012-03-30, REBALANCE ORDER SENT, GSG, Price: 34.78, Percentage: 0.00, Target Size: 0.00
# 2012-03-30, REBALANCE ORDER SENT, VNQ, Price: 45.47, Percentage: 0.00, Target Size: 0.00
# 2012-04-02, SELL EXECUTED, Price: 119.17, Size: -4, Cost: 416.10, Comm 0.48, RemSize: 0, RemCash: 5589.55
# 2012-04-02, BUY EXECUTED, Price: 102.97, Size: 5, Cost: 514.85, Comm 0.51, RemSize: 0, RemCash: 5589.55
# 2012-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2012-04-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0035299663688483788
#             Iterations: 20
#             Function evaluations: 141
#             Gradient evaluations: 20
# 2012-04-30, REBALANCE ORDER SENT, SPY, Price: 118.52, Percentage: 0.17, Target Size: 147.00
# 2012-04-30, REBALANCE ORDER SENT, EFA, Price: 41.60, Percentage: -0.00, Target Size: 0.00
# 2012-04-30, REBALANCE ORDER SENT, TIP, Price: 104.39, Percentage: 0.83, Target Size: 842.00
# 2012-04-30, REBALANCE ORDER SENT, GSG, Price: 34.66, Percentage: -0.00, Target Size: 0.00
# 2012-04-30, REBALANCE ORDER SENT, VNQ, Price: 46.78, Percentage: -0.00, Target Size: 0.00
# 2012-05-01, BUY EXECUTED, Price: 118.45, Size: 1, Cost: 118.45, Comm 0.12, RemSize: 0, RemCash: 5679.97
# 2012-05-01, SELL EXECUTED, Price: 104.60, Size: -2, Cost: 187.32, Comm 0.21, RemSize: 0, RemCash: 5679.97
# 2012-05-31 23:59:59.999989 strategy notify_timer with tid 0, when 2012-05-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0030398156485279167
#             Iterations: 19
#             Function evaluations: 133
#             Gradient evaluations: 19
# 2012-05-31, REBALANCE ORDER SENT, SPY, Price: 111.40, Percentage: 0.15, Target Size: 142.00
# 2012-05-31, REBALANCE ORDER SENT, EFA, Price: 36.96, Percentage: -0.00, Target Size: 0.00
# 2012-05-31, REBALANCE ORDER SENT, TIP, Price: 106.42, Percentage: 0.85, Target Size: 848.00
# 2012-05-31, REBALANCE ORDER SENT, GSG, Price: 30.23, Percentage: 0.00, Target Size: 0.00
# 2012-05-31, REBALANCE ORDER SENT, VNQ, Price: 44.67, Percentage: 0.00, Target Size: 0.00
# 2012-06-01, SELL EXECUTED, Price: 109.65, Size: -5, Cost: 520.62, Comm 0.55, RemSize: 0, RemCash: 5587.79
# 2012-06-01, BUY EXECUTED, Price: 106.54, Size: 6, Cost: 639.24, Comm 0.64, RemSize: 0, RemCash: 5587.79
# 2012-06-29 23:59:59.999989 strategy notify_timer with tid 0, when 2012-06-29 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002327448778596306
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2012-11-30, REBALANCE ORDER SENT, SPY, Price: 121.72, Percentage: 0.13, Target Size: 121.00
# 2012-11-30, REBALANCE ORDER SENT, EFA, Price: 43.61, Percentage: -0.00, Target Size: 0.00
# 2012-11-30, REBALANCE ORDER SENT, TIP, Price: 109.13, Percentage: 0.84, Target Size: 838.00
# 2012-11-30, REBALANCE ORDER SENT, GSG, Price: 32.96, Percentage: 0.00, Target Size: 10.00
# 2012-11-30, REBALANCE ORDER SENT, VNQ, Price: 46.62, Percentage: 0.03, Target Size: 62.00
# 2012-12-03, SELL EXECUTED, Price: 122.28, Size: -27, Cost: 2917.82, Comm 3.30, RemSize: 0, RemCash: 5867.81
# 2012-12-03, BUY EXECUTED, Price: 109.09, Size: 13, Cost: 1418.17, Comm 1.42, RemSize: 0, RemCash: 5867.81
# 2012-12-03, BUY EXECUTED, Price: 33.29, Size: 10, Cost: 332.90, Comm 0.33, RemSize: 0, RemCash: 5867.81
# 2012-12-03, BUY EXECUTED, Price: 46.82, Size: 34, Cost: 1591.88, Comm 1.59, RemSize: 0, RemCash: 5867.81
# 2012-12-31 23:59:59.999989 strategy notify_timer with tid 0, when 2012-12-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0022214813033731022
#             Iterations: 19
#             Function evaluations: 133
#             Gradient evaluations: 19
# 2012-12-31, REBALANCE ORDER SENT, SPY, Price: 122.81, Percentage: 0.15, Target Size: 137.00
# 2012-12-31, REBALANCE ORDER SENT, EFA, Price: 45.52, Percentage: 0.00, Target Size: 0.00
# 2012-12-31, REBALANCE ORDER SENT, TIP, Price: 108.23, Percentage: 0.84, Target Size: 845.00
# 2012-12-31, REBALANCE ORDER SENT, GSG, Price: 32.79, Percentage: 0.00, Target Size: 0.00
# 2012-12-31, REBALANCE ORDER SENT, VNQ, Price: 48.36, Percentage: 0.01, Target Size: 14.00
# 2013-01-02, BUY EXECUTED, Price: 125.13, Size: 16, Cost: 2002.08, Comm 2.00, RemSize: 0, RemCash: 5797.23
# 2013-01-02, BUY EXECUTED, Price: 108.01, Size: 7, Cost: 756.07, Comm 0.76, RemSize: 0, RemCash: 5797.23
# 2013-01-02, SELL EXECUTED, Price: 33.19, Size: -10, Cost: 332.90, Comm 0.33, RemSize: 0, RemCash: 5797.23
# 2013-01-02, SELL EXECUTED, Price: 49.19, Size: -48, Cost: 2256.29, Comm 2.36, RemSize: 0, RemCash: 5797.23
# 2013-01-02, OPERATION PROFIT, GROSS -1.00, NET -1.66
# 2013-01-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-01-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0021582710519625773
#             Iterations: 22
#             Function evaluations: 155
#             Gradient evaluations: 22
# 2013-01-31, REBALANCE ORDER SENT, SPY, Price: 129.09, Percentage: 0.14, Target Size: 115.00
# 2013-01-31, REBALANCE ORDER SENT, EFA, Price: 47.22, Percentage: 0.00, Target Size: 0.00
# 2013-01-31, REBALANCE ORDER SENT, TIP, Price: 107.67, Percentage: 0.84, Target Size: 855.00
# 2013-01-31, REBALANCE ORDER SENT, GSG, Price: 34.29, Percentage: 0.01, Target Size: 33.00
# 2013-01-31, REBALANCE ORDER SENT, VNQ, Price: 50.16, Percentage: 0.01, Target Size: 24.00
# 2013-02-01, SELL EXECUTED, Price: 129.91, Size: -22, Cost: 2421.32, Comm 2.86, RemSize: 0, RemCash: 5934.71
# 2013-02-01, BUY EXECUTED, Price: 107.91, Size: 10, Cost: 1079.10, Comm 1.08, RemSize: 0, RemCash: 5934.71
# 2013-02-01, BUY EXECUTED, Price: 34.29, Size: 33, Cost: 1131.57, Comm 1.13, RemSize: 0, RemCash: 5934.71
# 2013-02-01, BUY EXECUTED, Price: 50.43, Size: 10, Cost: 504.30, Comm 0.50, RemSize: 0, RemCash: 5934.71
# 2013-02-28 23:59:59.999989 strategy notify_timer with tid 0, when 2013-02-28 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002145536972640663
#             Iterations: 22
#             Function evaluations: 154
#             Gradient evaluations: 22
# 2013-02-28, REBALANCE ORDER SENT, SPY, Price: 130.74, Percentage: 0.16, Target Size: 130.00
# 2013-02-28, REBALANCE ORDER SENT, EFA, Price: 46.61, Percentage: 0.00, Target Size: 0.00
# 2013-02-28, REBALANCE ORDER SENT, TIP, Price: 107.87, Percentage: 0.83, Target Size: 843.00
# 2013-02-28, REBALANCE ORDER SENT, GSG, Price: 32.54, Percentage: 0.01, Target Size: 30.00
# 2013-02-28, REBALANCE ORDER SENT, VNQ, Price: 50.77, Percentage: 0.01, Target Size: 13.00
# 2013-03-01, BUY EXECUTED, Price: 130.29, Size: 15, Cost: 1954.35, Comm 1.95, RemSize: 0, RemCash: 5924.27
# 2013-03-01, SELL EXECUTED, Price: 107.81, Size: -12, Cost: 1134.47, Comm 1.29, RemSize: 0, RemCash: 5924.27
# 2013-03-01, SELL EXECUTED, Price: 32.35, Size: -3, Cost: 102.87, Comm 0.10, RemSize: 0, RemCash: 5924.27
# 2013-03-01, SELL EXECUTED, Price: 50.64, Size: -11, Cost: 532.76, Comm 0.56, RemSize: 0, RemCash: 5924.27
# 2013-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-04-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0021649334855208583
#             Iterations: 22
#             Function evaluations: 155
#             Gradient evaluations: 22
# 2013-04-30, REBALANCE ORDER SENT, SPY, Price: 138.31, Percentage: 0.13, Target Size: 105.00
# 2013-04-30, REBALANCE ORDER SENT, EFA, Price: 49.59, Percentage: -0.00, Target Size: 0.00
# 2013-04-30, REBALANCE ORDER SENT, TIP, Price: 108.96, Percentage: 0.80, Target Size: 815.00
# 2013-04-30, REBALANCE ORDER SENT, GSG, Price: 31.29, Percentage: 0.04, Target Size: 149.00
# 2013-04-30, REBALANCE ORDER SENT, VNQ, Price: 55.75, Percentage: 0.03, Target Size: 60.00
# 2013-05-01, SELL EXECUTED, Price: 138.01, Size: -25, Cost: 2809.86, Comm 3.45, RemSize: 0, RemCash: 6133.41
# 2013-05-01, SELL EXECUTED, Price: 109.02, Size: -28, Cost: 2647.10, Comm 3.05, RemSize: 0, RemCash: 6133.41
# 2013-05-01, BUY EXECUTED, Price: 30.73, Size: 119, Cost: 3656.87, Comm 3.66, RemSize: 0, RemCash: 6133.41
# 2013-05-01, BUY EXECUTED, Price: 55.83, Size: 47, Cost: 2624.01, Comm 2.62, RemSize: 0, RemCash: 6133.41
# 2013-05-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-05-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0022973784494991463
#             Iterations: 26
#             Function evaluations: 182
#             Gradient evaluations: 26
# 2013-05-31, REBALANCE ORDER SENT, SPY, Price: 141.58, Percentage: 0.17, Target Size: 128.00
# 2013-05-31, REBALANCE ORDER SENT, EFA, Price: 48.09, Percentage: 0.00, Target Size: 0.00
# 2013-05-31, REBALANCE ORDER SENT, TIP, Price: 104.39, Percentage: 0.78, Target Size: 806.00
# 2013-05-31, REBALANCE ORDER SENT, GSG, Price: 30.81, Percentage: 0.05, Target Size: 185.00
# 2013-05-31, REBALANCE ORDER SENT, VNQ, Price: 52.42, Percentage: -0.00, Target Size: 0.00
# 2013-06-03, BUY EXECUTED, Price: 141.91, Size: 23, Cost: 3263.93, Comm 3.26, RemSize: 0, RemCash: 5822.86
# 2013-06-03, SELL EXECUTED, Price: 103.92, Size: -9, Cost: 850.85, Comm 0.94, RemSize: 0, RemCash: 5822.86
# 2013-06-03, BUY EXECUTED, Price: 31.04, Size: 36, Cost: 1117.44, Comm 1.12, RemSize: 0, RemCash: 5822.86
# 2013-06-03, SELL EXECUTED, Price: 52.40, Size: -60, Cost: 3253.63, Comm 3.14, RemSize: 0, RemCash: 5822.86
# 2013-06-03, OPERATION PROFIT, GROSS 13.81, NET 1.04
# 2013-06-28 23:59:59.999989 strategy notify_timer with tid 0, when 2013-06-28 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002866517580928294
#             Iterations: 22
#             Function evaluations: 154
#             Gradient evaluations: 22
# 2013-06-28, REBALANCE ORDER SENT, SPY, Price: 139.69, Percentage: 0.13, Target Size: 95.00
# 2013-06-28, REBALANCE ORDER SENT, EFA, Price: 46.80, Percentage: -0.00, Target Size: 0.00
# 2013-06-28, REBALANCE ORDER SENT, TIP, Price: 100.42, Percentage: 0.80, Target Size: 836.00
# 2013-06-28, REBALANCE ORDER SENT, GSG, Price: 30.80, Percentage: 0.07, Target Size: 244.00
# 2013-06-28, REBALANCE ORDER SENT, VNQ, Price: 51.38, Percentage: -0.00, Target Size: 0.00
# 2013-07-01, SELL EXECUTED, Price: 140.42, Size: -33, Cost: 3884.03, Comm 4.63, RemSize: 0, RemCash: 5619.45
# 2013-07-01, BUY EXECUTED, Price: 99.98, Size: 30, Cost: 2999.40, Comm 3.00, RemSize: 0, RemCash: 5619.45
# 2013-07-01, BUY EXECUTED, Price: 30.99, Size: 59, Cost: 1828.41, Comm 1.83, RemSize: 0, RemCash: 5619.45
# 2013-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-07-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003019012050152538
#             Iterations: 23
#             Function evaluations: 161
#             Gradient evaluations: 23
# 2013-07-31, REBALANCE ORDER SENT, SPY, Price: 146.91, Percentage: 0.14, Target Size: 103.00
# 2013-07-31, REBALANCE ORDER SENT, EFA, Price: 49.29, Percentage: 0.00, Target Size: 0.00
# 2013-07-31, REBALANCE ORDER SENT, TIP, Price: 101.33, Percentage: 0.77, Target Size: 808.00
# 2013-07-31, REBALANCE ORDER SENT, GSG, Price: 32.54, Percentage: 0.09, Target Size: 290.00
# 2013-07-31, REBALANCE ORDER SENT, VNQ, Price: 51.84, Percentage: 0.00, Target Size: 0.00
# 2013-08-01, BUY EXECUTED, Price: 148.02, Size: 8, Cost: 1184.16, Comm 1.18, RemSize: 0, RemCash: 5743.97
# 2013-08-01, SELL EXECUTED, Price: 100.92, Size: -28, Cost: 2652.57, Comm 2.83, RemSize: 0, RemCash: 5743.97
# 2013-08-01, BUY EXECUTED, Price: 32.86, Size: 46, Cost: 1511.56, Comm 1.51, RemSize: 0, RemCash: 5743.97
# 2013-08-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-08-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003187961176761647
#             Iterations: 23
#             Function evaluations: 161
#             Gradient evaluations: 23
# 2013-08-30, REBALANCE ORDER SENT, SPY, Price: 142.50, Percentage: 0.15, Target Size: 106.00
# 2013-08-30, REBALANCE ORDER SENT, EFA, Price: 48.33, Percentage: 0.00, Target Size: 0.00
# 2013-08-30, REBALANCE ORDER SENT, TIP, Price: 99.48, Percentage: 0.74, Target Size: 780.00
# 2013-08-30, REBALANCE ORDER SENT, GSG, Price: 33.55, Percentage: 0.12, Target Size: 362.00
# 2013-08-30, REBALANCE ORDER SENT, VNQ, Price: 48.22, Percentage: -0.00, Target Size: 0.00
# 2013-09-03, BUY EXECUTED, Price: 143.88, Size: 3, Cost: 431.64, Comm 0.43, RemSize: 0, RemCash: 5660.74
# 2013-09-03, SELL EXECUTED, Price: 99.07, Size: -28, Cost: 2652.57, Comm 2.77, RemSize: 0, RemCash: 5660.74
# 2013-09-03, BUY EXECUTED, Price: 33.61, Size: 72, Cost: 2419.92, Comm 2.42, RemSize: 0, RemCash: 5660.74
# 2013-09-30 23:59:59.999989 strategy notify_timer with tid 0, when 2013-09-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033624234170201396
#             Iterations: 19
#             Function evaluations: 133
#             Gradient evaluations: 19
# 2013-09-30, REBALANCE ORDER SENT, SPY, Price: 147.01, Percentage: 0.17, Target Size: 124.00
# 2013-09-30, REBALANCE ORDER SENT, EFA, Price: 52.11, Percentage: 0.00, Target Size: 0.00
# 2013-09-30, REBALANCE ORDER SENT, TIP, Price: 101.22, Percentage: 0.72, Target Size: 757.00
# 2013-09-30, REBALANCE ORDER SENT, GSG, Price: 32.38, Percentage: 0.11, Target Size: 348.00
# 2013-09-30, REBALANCE ORDER SENT, VNQ, Price: 49.90, Percentage: -0.00, Target Size: 0.00
# 2013-10-01, BUY EXECUTED, Price: 147.12, Size: 18, Cost: 2648.16, Comm 2.65, RemSize: 0, RemCash: 5783.60
# 2013-10-01, SELL EXECUTED, Price: 101.20, Size: -23, Cost: 2178.90, Comm 2.33, RemSize: 0, RemCash: 5783.60
# 2013-10-01, SELL EXECUTED, Price: 32.06, Size: -14, Cost: 447.18, Comm 0.45, RemSize: 0, RemCash: 5783.60
# 2013-10-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-10-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003406643872431929
#             Iterations: 20
#             Function evaluations: 140
#             Gradient evaluations: 20
# 2013-10-31, REBALANCE ORDER SENT, SPY, Price: 153.82, Percentage: 0.16, Target Size: 111.00
# 2013-10-31, REBALANCE ORDER SENT, EFA, Price: 53.81, Percentage: -0.00, Target Size: 0.00
# 2013-10-31, REBALANCE ORDER SENT, TIP, Price: 101.57, Percentage: 0.73, Target Size: 774.00
# 2013-10-31, REBALANCE ORDER SENT, GSG, Price: 31.91, Percentage: 0.11, Target Size: 354.00
# 2013-10-31, REBALANCE ORDER SENT, VNQ, Price: 52.16, Percentage: 0.00, Target Size: 0.00
# 2013-11-01, SELL EXECUTED, Price: 154.02, Size: -13, Cost: 1619.26, Comm 2.00, RemSize: 0, RemCash: 5870.10
# 2013-11-01, BUY EXECUTED, Price: 101.33, Size: 17, Cost: 1722.61, Comm 1.72, RemSize: 0, RemCash: 5870.10
# 2013-11-01, BUY EXECUTED, Price: 31.54, Size: 6, Cost: 189.24, Comm 0.19, RemSize: 0, RemCash: 5870.10
# 2013-11-29 23:59:59.999989 strategy notify_timer with tid 0, when 2013-11-29 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003524377546792355
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2013-11-29, REBALANCE ORDER SENT, SPY, Price: 158.38, Percentage: 0.16, Target Size: 108.00
# 2013-11-29, REBALANCE ORDER SENT, EFA, Price: 54.10, Percentage: -0.00, Target Size: 0.00
# 2013-11-29, REBALANCE ORDER SENT, TIP, Price: 100.50, Percentage: 0.74, Target Size: 784.00
# 2013-11-29, REBALANCE ORDER SENT, GSG, Price: 31.76, Percentage: 0.10, Target Size: 340.00
# 2013-11-29, REBALANCE ORDER SENT, VNQ, Price: 49.42, Percentage: 0.00, Target Size: 0.00
# 2013-12-02, SELL EXECUTED, Price: 158.46, Size: -3, Cost: 373.68, Comm 0.48, RemSize: 0, RemCash: 5782.47
# 2013-12-02, BUY EXECUTED, Price: 100.39, Size: 10, Cost: 1003.90, Comm 1.00, RemSize: 0, RemCash: 5782.47
# 2013-12-02, SELL EXECUTED, Price: 31.63, Size: -14, Cost: 447.09, Comm 0.44, RemSize: 0, RemCash: 5782.47
# 2013-12-31 23:59:59.999989 strategy notify_timer with tid 0, when 2013-12-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003542459283877439
#             Iterations: 20
#             Function evaluations: 140
#             Gradient evaluations: 20
# 2013-12-31, REBALANCE ORDER SENT, SPY, Price: 162.48, Percentage: 0.16, Target Size: 105.00
# 2013-12-31, REBALANCE ORDER SENT, EFA, Price: 55.28, Percentage: -0.00, Target Size: 0.00
# 2013-12-31, REBALANCE ORDER SENT, TIP, Price: 99.04, Percentage: 0.73, Target Size: 783.00
# 2013-12-31, REBALANCE ORDER SENT, GSG, Price: 32.19, Percentage: 0.11, Target Size: 359.00
# 2013-12-31, REBALANCE ORDER SENT, VNQ, Price: 49.47, Percentage: 0.00, Target Size: 0.00
# 2014-01-02, SELL EXECUTED, Price: 161.86, Size: -3, Cost: 373.68, Comm 0.49, RemSize: 0, RemCash: 5759.88
# 2014-01-02, SELL EXECUTED, Price: 99.12, Size: -1, Cost: 94.95, Comm 0.10, RemSize: 0, RemCash: 5759.88
# 2014-01-02, BUY EXECUTED, Price: 31.90, Size: 19, Cost: 606.10, Comm 0.61, RemSize: 0, RemCash: 5759.88
# 2014-01-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-01-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003499987862756522
#             Iterations: 22
#             Function evaluations: 154
#             Gradient evaluations: 22
# 2014-01-31, REBALANCE ORDER SENT, SPY, Price: 156.76, Percentage: 0.18, Target Size: 124.00
# 2014-01-31, REBALANCE ORDER SENT, EFA, Price: 52.41, Percentage: -0.00, Target Size: 0.00
# 2014-01-31, REBALANCE ORDER SENT, TIP, Price: 101.12, Percentage: 0.71, Target Size: 755.00
# 2014-01-31, REBALANCE ORDER SENT, GSG, Price: 31.48, Percentage: 0.10, Target Size: 353.00
# 2014-01-31, REBALANCE ORDER SENT, VNQ, Price: 51.59, Percentage: 0.00, Target Size: 0.00
# 2014-02-03, BUY EXECUTED, Price: 156.57, Size: 19, Cost: 2974.83, Comm 2.97, RemSize: 0, RemCash: 5799.88
# 2014-02-03, SELL EXECUTED, Price: 101.16, Size: -28, Cost: 2658.59, Comm 2.83, RemSize: 0, RemCash: 5799.88
# 2014-02-03, SELL EXECUTED, Price: 31.39, Size: -6, Cost: 191.60, Comm 0.19, RemSize: 0, RemCash: 5799.88
# 2014-02-28 23:59:59.999989 strategy notify_timer with tid 0, when 2014-02-28 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00350645478742823
#             Iterations: 22
#             Function evaluations: 154
#             Gradient evaluations: 22
# 2014-02-28, REBALANCE ORDER SENT, SPY, Price: 163.89, Percentage: 0.18, Target Size: 116.00
# 2014-02-28, REBALANCE ORDER SENT, EFA, Price: 55.62, Percentage: -0.00, Target Size: 0.00
# 2014-02-28, REBALANCE ORDER SENT, TIP, Price: 101.56, Percentage: 0.71, Target Size: 759.00
# 2014-02-28, REBALANCE ORDER SENT, GSG, Price: 32.99, Percentage: 0.12, Target Size: 379.00
# 2014-02-28, REBALANCE ORDER SENT, VNQ, Price: 54.20, Percentage: 0.00, Target Size: 0.00
# 2014-03-03, SELL EXECUTED, Price: 162.45, Size: -8, Cost: 1035.71, Comm 1.30, RemSize: 0, RemCash: 5819.04
# 2014-03-03, BUY EXECUTED, Price: 101.78, Size: 4, Cost: 407.12, Comm 0.41, RemSize: 0, RemCash: 5819.04
# 2014-03-03, BUY EXECUTED, Price: 33.49, Size: 26, Cost: 870.74, Comm 0.87, RemSize: 0, RemCash: 5819.04
# 2014-03-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-03-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033634412278240617
#             Iterations: 21
#             Function evaluations: 147
#             Gradient evaluations: 21
# 2014-03-31, REBALANCE ORDER SENT, SPY, Price: 165.25, Percentage: 0.20, Target Size: 132.00
# 2014-03-31, REBALANCE ORDER SENT, EFA, Price: 55.36, Percentage: 0.00, Target Size: 0.00
# 2014-03-31, REBALANCE ORDER SENT, TIP, Price: 101.02, Percentage: 0.70, Target Size: 751.00
# 2014-03-31, REBALANCE ORDER SENT, GSG, Price: 32.97, Percentage: 0.10, Target Size: 324.00
# 2014-03-31, REBALANCE ORDER SENT, VNQ, Price: 54.47, Percentage: 0.00, Target Size: 0.00
# 2014-04-01, BUY EXECUTED, Price: 165.79, Size: 16, Cost: 2652.64, Comm 2.65, RemSize: 0, RemCash: 5773.04
# 2014-04-01, SELL EXECUTED, Price: 100.85, Size: -8, Cost: 759.89, Comm 0.81, RemSize: 0, RemCash: 5773.04
# 2014-04-01, SELL EXECUTED, Price: 32.82, Size: -55, Cost: 1762.19, Comm 1.81, RemSize: 0, RemCash: 5773.04
# 2014-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-04-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0027883033132650617
#             Iterations: 17
#             Function evaluations: 119
#             Gradient evaluations: 17
# 2014-04-30, REBALANCE ORDER SENT, SPY, Price: 166.40, Percentage: 0.20, Target Size: 134.00
# 2014-04-30, REBALANCE ORDER SENT, EFA, Price: 56.29, Percentage: -0.00, Target Size: 0.00
# 2014-04-30, REBALANCE ORDER SENT, TIP, Price: 102.36, Percentage: 0.72, Target Size: 768.00
# 2014-04-30, REBALANCE ORDER SENT, GSG, Price: 33.30, Percentage: 0.08, Target Size: 259.00
# 2014-04-30, REBALANCE ORDER SENT, VNQ, Price: 56.26, Percentage: 0.00, Target Size: 0.00
# 2014-05-01, BUY EXECUTED, Price: 166.32, Size: 2, Cost: 332.64, Comm 0.33, RemSize: 0, RemCash: 5842.29
# 2014-05-01, BUY EXECUTED, Price: 102.44, Size: 17, Cost: 1741.48, Comm 1.74, RemSize: 0, RemCash: 5842.29
# 2014-05-01, SELL EXECUTED, Price: 33.04, Size: -65, Cost: 2082.59, Comm 2.15, RemSize: 0, RemCash: 5842.29
# 2014-05-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-05-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0026677478049079648
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2014-05-30, REBALANCE ORDER SENT, SPY, Price: 170.26, Percentage: 0.20, Target Size: 127.00
# 2014-05-30, REBALANCE ORDER SENT, EFA, Price: 57.19, Percentage: -0.00, Target Size: 0.00
# 2014-05-30, REBALANCE ORDER SENT, TIP, Price: 104.40, Percentage: 0.73, Target Size: 784.00
# 2014-05-30, REBALANCE ORDER SENT, GSG, Price: 33.13, Percentage: 0.07, Target Size: 237.00
# 2014-05-30, REBALANCE ORDER SENT, VNQ, Price: 57.61, Percentage: 0.00, Target Size: 0.00
# 2014-06-02, SELL EXECUTED, Price: 170.50, Size: -7, Cost: 940.46, Comm 1.19, RemSize: 0, RemCash: 6090.05
# 2014-06-02, BUY EXECUTED, Price: 104.26, Size: 16, Cost: 1668.16, Comm 1.67, RemSize: 0, RemCash: 6090.05
# 2014-06-02, SELL EXECUTED, Price: 33.00, Size: -22, Cost: 704.88, Comm 0.73, RemSize: 0, RemCash: 6090.05
# 2014-06-30 23:59:59.999989 strategy notify_timer with tid 0, when 2014-06-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002418398114557153
#             Iterations: 18
#             Function evaluations: 126
#             Gradient evaluations: 18
# 2014-06-30, REBALANCE ORDER SENT, SPY, Price: 173.77, Percentage: 0.20, Target Size: 127.00
# 2014-06-30, REBALANCE ORDER SENT, EFA, Price: 57.71, Percentage: 0.00, Target Size: 0.00
# 2014-06-30, REBALANCE ORDER SENT, TIP, Price: 104.79, Percentage: 0.76, Target Size: 814.00
# 2014-06-30, REBALANCE ORDER SENT, GSG, Price: 33.92, Percentage: 0.04, Target Size: 144.00
# 2014-06-30, REBALANCE ORDER SENT, VNQ, Price: 58.26, Percentage: -0.00, Target Size: 0.00
# 2014-07-01, BUY EXECUTED, Price: 104.56, Size: 30, Cost: 3136.80, Comm 3.14, RemSize: 0, RemCash: 6097.80
# 2014-07-01, SELL EXECUTED, Price: 33.88, Size: -93, Cost: 2979.71, Comm 3.15, RemSize: 0, RemCash: 6097.80
# 2014-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2014-07-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002260568181723301
#             Iterations: 23
#             Function evaluations: 161
#             Gradient evaluations: 23
# 2014-07-31, REBALANCE ORDER SENT, SPY, Price: 171.44, Percentage: 0.21, Target Size: 137.00
# 2014-07-31, REBALANCE ORDER SENT, EFA, Price: 56.21, Percentage: -0.00, Target Size: 0.00
# 2014-07-31, REBALANCE ORDER SENT, TIP, Price: 104.69, Percentage: 0.74, Target Size: 791.00
# 2014-07-31, REBALANCE ORDER SENT, GSG, Price: 32.00, Percentage: 0.05, Target Size: 169.00
# 2014-07-31, REBALANCE ORDER SENT, VNQ, Price: 58.31, Percentage: 0.00, Target Size: 0.00
# ...
# 2018-12-31, REBALANCE ORDER SENT, GSG, Price: 14.02, Percentage: 0.07, Target Size: 603.00
# 2018-12-31, REBALANCE ORDER SENT, VNQ, Price: 70.72, Percentage: 0.08, Target Size: 130.00
# 2019-01-02, SELL EXECUTED, Price: 238.95, Size: -3, Cost: 536.97, Comm 0.72, RemSize: 0, RemCash: 6258.89
# 2019-01-02, BUY EXECUTED, Price: 107.11, Size: 18, Cost: 1927.98, Comm 1.93, RemSize: 0, RemCash: 6258.89
# 2019-01-02, SELL EXECUTED, Price: 13.82, Size: -27, Cost: 554.69, Comm 0.37, RemSize: 0, RemCash: 6258.89
# 2019-01-02, SELL EXECUTED, Price: 69.76, Size: -9, Cost: 545.09, Comm 0.63, RemSize: 0, RemCash: 6258.89
# 2019-01-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-01-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 5.531145296901167e-14
#             Iterations: 45
#             Function evaluations: 317
#             Gradient evaluations: 45
# 2019-01-31, REBALANCE ORDER SENT, SPY, Price: 262.21, Percentage: 0.08, Target Size: 34.00
# 2019-01-31, REBALANCE ORDER SENT, EFA, Price: 59.82, Percentage: 0.10, Target Size: 190.00
# 2019-01-31, REBALANCE ORDER SENT, TIP, Price: 108.57, Percentage: 0.67, Target Size: 730.00
# 2019-01-31, REBALANCE ORDER SENT, GSG, Price: 15.19, Percentage: 0.08, Target Size: 590.00
# 2019-01-31, REBALANCE ORDER SENT, VNQ, Price: 79.11, Percentage: 0.09, Target Size: 128.00
# 2019-02-01, BUY EXECUTED, Price: 262.42, Size: 1, Cost: 262.42, Comm 0.26, RemSize: 0, RemCash: 6617.20
# 2019-02-01, BUY EXECUTED, Price: 59.83, Size: 1, Cost: 59.83, Comm 0.06, RemSize: 0, RemCash: 6617.20
# 2019-02-01, SELL EXECUTED, Price: 108.49, Size: -3, Cost: 307.01, Comm 0.33, RemSize: 0, RemCash: 6617.20
# 2019-02-01, SELL EXECUTED, Price: 15.21, Size: -13, Cost: 267.07, Comm 0.20, RemSize: 0, RemCash: 6617.20
# 2019-02-01, SELL EXECUTED, Price: 79.18, Size: -2, Cost: 121.13, Comm 0.16, RemSize: 0, RemCash: 6617.20
# 2019-02-28 23:59:59.999989 strategy notify_timer with tid 0, when 2019-02-28 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 8.500341950801713e-15
#             Iterations: 41
#             Function evaluations: 288
#             Gradient evaluations: 41
# 2019-02-28, REBALANCE ORDER SENT, SPY, Price: 270.71, Percentage: 0.08, Target Size: 33.00
# 2019-02-28, REBALANCE ORDER SENT, EFA, Price: 61.34, Percentage: 0.09, Target Size: 180.00
# 2019-02-28, REBALANCE ORDER SENT, TIP, Price: 108.39, Percentage: 0.67, Target Size: 741.00
# 2019-02-28, REBALANCE ORDER SENT, GSG, Price: 15.72, Percentage: 0.07, Target Size: 558.00
# 2019-02-28, REBALANCE ORDER SENT, VNQ, Price: 79.66, Percentage: 0.09, Target Size: 130.00
# 2019-03-01, SELL EXECUTED, Price: 272.42, Size: -1, Cost: 181.44, Comm 0.27, RemSize: 0, RemCash: 6655.96
# 2019-03-01, SELL EXECUTED, Price: 61.69, Size: -10, Cost: 523.10, Comm 0.62, RemSize: 0, RemCash: 6655.96
# 2019-03-01, BUY EXECUTED, Price: 108.33, Size: 11, Cost: 1191.63, Comm 1.19, RemSize: 0, RemCash: 6655.96
# 2019-03-01, SELL EXECUTED, Price: 15.72, Size: -32, Cost: 657.41, Comm 0.50, RemSize: 0, RemCash: 6655.96
# 2019-03-01, BUY EXECUTED, Price: 79.61, Size: 2, Cost: 159.22, Comm 0.16, RemSize: 0, RemCash: 6655.96
# 2019-03-29 23:59:59.999989 strategy notify_timer with tid 0, when 2019-03-29 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.039479643323183e-15
#             Iterations: 40
#             Function evaluations: 282
#             Gradient evaluations: 40
# 2019-03-29, REBALANCE ORDER SENT, SPY, Price: 275.61, Percentage: 0.08, Target Size: 34.00
# 2019-03-29, REBALANCE ORDER SENT, EFA, Price: 61.90, Percentage: 0.09, Target Size: 180.00
# 2019-03-29, REBALANCE ORDER SENT, TIP, Price: 110.53, Percentage: 0.67, Target Size: 738.00
# 2019-03-29, REBALANCE ORDER SENT, GSG, Price: 15.95, Percentage: 0.07, Target Size: 562.00
# 2019-03-29, REBALANCE ORDER SENT, VNQ, Price: 83.01, Percentage: 0.09, Target Size: 131.00
# 2019-04-01, BUY EXECUTED, Price: 277.78, Size: 1, Cost: 277.78, Comm 0.28, RemSize: 0, RemCash: 6561.24
# 2019-04-01, SELL EXECUTED, Price: 110.37, Size: -3, Cost: 307.27, Comm 0.33, RemSize: 0, RemCash: 6561.24
# 2019-04-01, BUY EXECUTED, Price: 16.05, Size: 4, Cost: 64.20, Comm 0.06, RemSize: 0, RemCash: 6561.24
# 2019-04-01, BUY EXECUTED, Price: 83.10, Size: 1, Cost: 83.10, Comm 0.08, RemSize: 0, RemCash: 6561.24
# 2019-04-30 23:59:59.999989 strategy notify_timer with tid 0, when 2019-04-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.939273429230063e-14
#             Iterations: 43
#             Function evaluations: 301
#             Gradient evaluations: 43
# 2019-04-30, REBALANCE ORDER SENT, SPY, Price: 286.87, Percentage: 0.08, Target Size: 33.00
# 2019-04-30, REBALANCE ORDER SENT, EFA, Price: 63.72, Percentage: 0.10, Target Size: 190.00
# 2019-04-30, REBALANCE ORDER SENT, TIP, Price: 110.77, Percentage: 0.65, Target Size: 726.00
# 2019-04-30, REBALANCE ORDER SENT, GSG, Price: 16.39, Percentage: 0.08, Target Size: 612.00
# 2019-04-30, REBALANCE ORDER SENT, VNQ, Price: 82.88, Percentage: 0.09, Target Size: 130.00
# 2019-05-01, SELL EXECUTED, Price: 287.55, Size: -1, Cost: 184.28, Comm 0.29, RemSize: 0, RemCash: 6798.53
# 2019-05-01, BUY EXECUTED, Price: 63.81, Size: 10, Cost: 638.10, Comm 0.64, RemSize: 0, RemCash: 6798.53
# 2019-05-01, SELL EXECUTED, Price: 110.76, Size: -12, Cost: 1229.09, Comm 1.33, RemSize: 0, RemCash: 6798.53
# 2019-05-01, BUY EXECUTED, Price: 16.42, Size: 50, Cost: 821.00, Comm 0.82, RemSize: 0, RemCash: 6798.53
# 2019-05-01, SELL EXECUTED, Price: 82.88, Size: -1, Cost: 61.03, Comm 0.08, RemSize: 0, RemCash: 6798.53
# 2019-05-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-05-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1865746935766758e-13
#             Iterations: 32
#             Function evaluations: 224
#             Gradient evaluations: 32
# 2019-05-31, REBALANCE ORDER SENT, SPY, Price: 268.58, Percentage: 0.08, Target Size: 34.00
# 2019-05-31, REBALANCE ORDER SENT, EFA, Price: 60.51, Percentage: 0.09, Target Size: 188.00
# 2019-05-31, REBALANCE ORDER SENT, TIP, Price: 112.71, Percentage: 0.66, Target Size: 720.00
# 2019-05-31, REBALANCE ORDER SENT, GSG, Price: 15.01, Percentage: 0.08, Target Size: 659.00
# 2019-05-31, REBALANCE ORDER SENT, VNQ, Price: 83.00, Percentage: 0.09, Target Size: 130.00
# 2019-06-03, BUY EXECUTED, Price: 268.62, Size: 1, Cost: 268.62, Comm 0.27, RemSize: 0, RemCash: 6614.79
# 2019-06-03, SELL EXECUTED, Price: 60.69, Size: -2, Cost: 105.83, Comm 0.12, RemSize: 0, RemCash: 6614.79
# 2019-06-03, SELL EXECUTED, Price: 112.81, Size: -6, Cost: 614.55, Comm 0.68, RemSize: 0, RemCash: 6614.79
# 2019-06-03, BUY EXECUTED, Price: 15.14, Size: 47, Cost: 711.58, Comm 0.71, RemSize: 0, RemCash: 6614.79
# 2019-06-28 23:59:59.999989 strategy notify_timer with tid 0, when 2019-06-28 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.287629011542407e-14
#             Iterations: 36
#             Function evaluations: 252
#             Gradient evaluations: 36
# 2019-06-28, REBALANCE ORDER SENT, SPY, Price: 287.27, Percentage: 0.08, Target Size: 34.00
# 2019-06-28, REBALANCE ORDER SENT, EFA, Price: 64.09, Percentage: 0.10, Target Size: 194.00
# 2019-06-28, REBALANCE ORDER SENT, TIP, Price: 113.56, Percentage: 0.64, Target Size: 702.00
# 2019-06-28, REBALANCE ORDER SENT, GSG, Price: 15.65, Percentage: 0.09, Target Size: 695.00
# 2019-06-28, REBALANCE ORDER SENT, VNQ, Price: 84.29, Percentage: 0.09, Target Size: 140.00
# 2019-07-01, BUY EXECUTED, Price: 64.73, Size: 6, Cost: 388.38, Comm 0.39, RemSize: 0, RemCash: 6846.81
# 2019-07-01, SELL EXECUTED, Price: 113.66, Size: -18, Cost: 1843.64, Comm 2.05, RemSize: 0, RemCash: 6846.81
# 2019-07-01, BUY EXECUTED, Price: 15.92, Size: 36, Cost: 573.12, Comm 0.57, RemSize: 0, RemCash: 6846.81
# 2019-07-01, BUY EXECUTED, Price: 84.85, Size: 10, Cost: 848.50, Comm 0.85, RemSize: 0, RemCash: 6846.81
# 2019-07-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-07-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.5988207320418608e-14
#             Iterations: 45
#             Function evaluations: 315
#             Gradient evaluations: 45
# 2019-07-31, REBALANCE ORDER SENT, SPY, Price: 291.61, Percentage: 0.08, Target Size: 35.00
# 2019-07-31, REBALANCE ORDER SENT, EFA, Price: 62.84, Percentage: 0.10, Target Size: 202.00
# 2019-07-31, REBALANCE ORDER SENT, TIP, Price: 113.92, Percentage: 0.63, Target Size: 695.00
# 2019-07-31, REBALANCE ORDER SENT, GSG, Price: 15.58, Percentage: 0.09, Target Size: 692.00
# 2019-07-31, REBALANCE ORDER SENT, VNQ, Price: 85.72, Percentage: 0.10, Target Size: 142.00
# 2019-08-01, BUY EXECUTED, Price: 291.78, Size: 1, Cost: 291.78, Comm 0.29, RemSize: 0, RemCash: 6720.74
# 2019-08-01, BUY EXECUTED, Price: 62.92, Size: 8, Cost: 503.36, Comm 0.50, RemSize: 0, RemCash: 6720.74
# 2019-08-01, SELL EXECUTED, Price: 113.74, Size: -7, Cost: 716.97, Comm 0.80, RemSize: 0, RemCash: 6720.74
# 2019-08-01, SELL EXECUTED, Price: 15.46, Size: -3, Cost: 58.85, Comm 0.05, RemSize: 0, RemCash: 6720.74
# 2019-08-01, BUY EXECUTED, Price: 85.84, Size: 2, Cost: 171.68, Comm 0.17, RemSize: 0, RemCash: 6720.74
# 2019-08-30 23:59:59.999989 strategy notify_timer with tid 0, when 2019-08-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.91282014318122e-14
#             Iterations: 41
#             Function evaluations: 288
#             Gradient evaluations: 41
# 2019-08-30, REBALANCE ORDER SENT, SPY, Price: 286.73, Percentage: 0.08, Target Size: 34.00
# 2019-08-30, REBALANCE ORDER SENT, EFA, Price: 61.63, Percentage: 0.10, Target Size: 207.00
# 2019-08-30, REBALANCE ORDER SENT, TIP, Price: 116.57, Percentage: 0.64, Target Size: 693.00
# 2019-08-30, REBALANCE ORDER SENT, GSG, Price: 14.82, Percentage: 0.09, Target Size: 732.00
# 2019-08-30, REBALANCE ORDER SENT, VNQ, Price: 88.93, Percentage: 0.09, Target Size: 134.00
# 2019-09-03, SELL EXECUTED, Price: 284.88, Size: -1, Cost: 189.76, Comm 0.28, RemSize: 0, RemCash: 7060.57
# 2019-09-03, BUY EXECUTED, Price: 61.28, Size: 5, Cost: 306.40, Comm 0.31, RemSize: 0, RemCash: 7060.57
# 2019-09-03, SELL EXECUTED, Price: 116.49, Size: -2, Cost: 204.85, Comm 0.23, RemSize: 0, RemCash: 7060.57
# 2019-09-03, BUY EXECUTED, Price: 14.52, Size: 40, Cost: 580.80, Comm 0.58, RemSize: 0, RemCash: 7060.57
# 2019-09-03, SELL EXECUTED, Price: 88.91, Size: -8, Cost: 504.44, Comm 0.71, RemSize: 0, RemCash: 7060.57
# 2019-09-30 23:59:59.999989 strategy notify_timer with tid 0, when 2019-09-30 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.1286313625354617e-13
#             Iterations: 38
#             Function evaluations: 267
#             Gradient evaluations: 38
# 2019-09-30, REBALANCE ORDER SENT, SPY, Price: 292.31, Percentage: 0.09, Target Size: 38.00
# 2019-09-30, REBALANCE ORDER SENT, EFA, Price: 63.58, Percentage: 0.12, Target Size: 229.00
# 2019-09-30, REBALANCE ORDER SENT, TIP, Price: 115.28, Percentage: 0.61, Target Size: 671.00
# 2019-09-30, REBALANCE ORDER SENT, GSG, Price: 15.05, Percentage: 0.09, Target Size: 724.00
# 2019-09-30, REBALANCE ORDER SENT, VNQ, Price: 90.65, Percentage: 0.10, Target Size: 137.00
# 2019-10-01, BUY EXECUTED, Price: 293.26, Size: 4, Cost: 1173.04, Comm 1.17, RemSize: 0, RemCash: 6862.50
# 2019-10-01, BUY EXECUTED, Price: 63.40, Size: 22, Cost: 1394.80, Comm 1.39, RemSize: 0, RemCash: 6862.50
# 2019-10-01, SELL EXECUTED, Price: 114.83, Size: -22, Cost: 2253.33, Comm 2.53, RemSize: 0, RemCash: 6862.50
# 2019-10-01, SELL EXECUTED, Price: 15.10, Size: -8, Cost: 154.70, Comm 0.12, RemSize: 0, RemCash: 6862.50
# 2019-10-01, BUY EXECUTED, Price: 90.60, Size: 3, Cost: 271.80, Comm 0.27, RemSize: 0, RemCash: 6862.50
# 2019-10-31 23:59:59.999989 strategy notify_timer with tid 0, when 2019-10-31 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0860173869874845e-13
#             Iterations: 44
#             Function evaluations: 308
#             Gradient evaluations: 44
# 2019-10-31, REBALANCE ORDER SENT, SPY, Price: 298.77, Percentage: 0.10, Target Size: 44.00
# 2019-10-31, REBALANCE ORDER SENT, EFA, Price: 65.74, Percentage: 0.12, Target Size: 233.00
# 2019-10-31, REBALANCE ORDER SENT, TIP, Price: 115.25, Percentage: 0.56, Target Size: 614.00
# 2019-10-31, REBALANCE ORDER SENT, GSG, Price: 15.17, Percentage: 0.10, Target Size: 799.00
# 2019-10-31, REBALANCE ORDER SENT, VNQ, Price: 91.67, Percentage: 0.12, Target Size: 171.00
# 2019-11-01, BUY EXECUTED, Price: 300.33, Size: 6, Cost: 1801.98, Comm 1.80, RemSize: 0, RemCash: 7085.55
# 2019-11-01, BUY EXECUTED, Price: 66.16, Size: 4, Cost: 264.64, Comm 0.26, RemSize: 0, RemCash: 7085.55
# 2019-11-01, SELL EXECUTED, Price: 115.30, Size: -57, Cost: 5838.18, Comm 6.57, RemSize: 0, RemCash: 7085.55
# 2019-11-01, BUY EXECUTED, Price: 15.32, Size: 75, Cost: 1149.00, Comm 1.15, RemSize: 0, RemCash: 7085.55
# 2019-11-01, BUY EXECUTED, Price: 91.78, Size: 34, Cost: 3120.52, Comm 3.12, RemSize: 0, RemCash: 7085.55
# 2019-11-29 23:59:59.999989 strategy notify_timer with tid 0, when 2019-11-29 00:00:00 cheat False
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2942481537419362e-13
#             Iterations: 45
#             Function evaluations: 315
#             Gradient evaluations: 45
# 2019-11-29, REBALANCE ORDER SENT, SPY, Price: 309.58, Percentage: 0.11, Target Size: 44.00
# 2019-11-29, REBALANCE ORDER SENT, EFA, Price: 66.48, Percentage: 0.13, Target Size: 243.00
# 2019-11-29, REBALANCE ORDER SENT, TIP, Price: 115.59, Percentage: 0.55, Target Size: 611.00
# 2019-11-29, REBALANCE ORDER SENT, GSG, Price: 15.23, Percentage: 0.09, Target Size: 795.00
# 2019-11-29, REBALANCE ORDER SENT, VNQ, Price: 90.47, Percentage: 0.12, Target Size: 167.00
# 2019-12-02, BUY EXECUTED, Price: 66.40, Size: 10, Cost: 664.00, Comm 0.66, RemSize: 0, RemCash: 7187.47
# 2019-12-02, SELL EXECUTED, Price: 115.17, Size: -3, Cost: 307.27, Comm 0.35, RemSize: 0, RemCash: 7187.47
# 2019-12-02, SELL EXECUTED, Price: 15.35, Size: -4, Cost: 75.84, Comm 0.06, RemSize: 0, RemCash: 7187.47
# 2019-12-02, SELL EXECUTED, Price: 90.11, Size: -4, Cost: 277.00, Comm 0.36, RemSize: 0, RemCash: 7187.47
# <backtrader.metabase.ItemCollection object at 0x000002238CB04408>
# 2019-12-30, ROI:        36.77%
# 2019-12-30, risk_parity ending Value 136773.52
# Final Portfolio Value: 136773.52, Sharpe Ratio: 0.43, DrawDown: 0.15, MoneyDown 204.52
#                           gmv    sharpe  diversified  risk_parity  equal_weights
# Annual return        0.037149  0.025520     0.032405     0.035254       0.053769
# Cumulative returns   0.396035  0.259229     0.338708     0.372879       0.614532
# Annual volatility    0.040158  0.075958     0.046671     0.054546       0.106037
# Sharpe ratio         0.928454  0.369845     0.706706     0.662512       0.547052
# Calmar ratio         0.483256  0.141066     0.289862     0.268421       0.243159
# Stability            0.904098  0.682156     0.749033     0.784332       0.766989
# Max drawdown        -0.076872 -0.180910    -0.111796    -0.131339      -0.221126
# Omega ratio          1.172122  1.077346     1.128652     1.121542       1.102723
# Sortino ratio        1.324288  0.491857     0.996348     0.929500       0.761159
# Skew                -0.263738 -0.839470    -0.326846    -0.362057      -0.416300
# Kurtosis             3.390843  8.208474     3.745888     4.529737       5.457346
# Tail ratio           0.994677  0.872240     0.991897     0.954949       0.932250
# Daily value at risk -0.004911 -0.009458    -0.005749    -0.006729      -0.013129
# <img src="data:image/png;base64,..." width="360">
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="1800">

# %%
pd.set_option('display.width', 1000)
print(perf_stats_all)
# Out:
#                           gmv    sharpe  diversified  risk_parity  equal_weights
# Annual return        0.037149  0.025520     0.032405     0.035254       0.053769
# Cumulative returns   0.396035  0.259229     0.338708     0.372879       0.614532
# Annual volatility    0.040158  0.075958     0.046671     0.054546       0.106037
# Sharpe ratio         0.928454  0.369845     0.706706     0.662512       0.547052
# Calmar ratio         0.483256  0.141066     0.289862     0.268421       0.243159
# Stability            0.904098  0.682156     0.749033     0.784332       0.766989
# Max drawdown        -0.076872 -0.180910    -0.111796    -0.131339      -0.221126
# Omega ratio          1.172122  1.077346     1.128652     1.121542       1.102723
# Sortino ratio        1.324288  0.491857     0.996348     0.929500       0.761159
# Skew                -0.263738 -0.839470    -0.326846    -0.362057      -0.416300
# Kurtosis             3.390843  8.208474     3.745888     4.529737       5.457346
# Tail ratio           0.994677  0.872240     0.991897     0.954949       0.932250
# Daily value at risk -0.004911 -0.009458    -0.005749    -0.006729      -0.013129

# %%
portfolio_value_all = pd.DataFrame()
for s in strategies:
    port_value = dict_results[s]['positions'].sum(axis=1)
    port_value.name = s
    portfolio_value_all = pd.concat([portfolio_value_all, port_value], axis=1)
port_value = df_constituents_value.Benchmark.copy()
port_value.name = 'equal_weights'
portfolio_value_all = pd.concat([portfolio_value_all, port_value], axis=1)

fig, ax = plt.subplots(2, 1, figsize=(5, 12))
portfolio_value_all.plot(ax=ax[0])
df_constituents_value[etfs].plot(ax=ax[1])
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="819">

# %%
fig, ax = plt.subplots(5, 1, figsize=(10, 35))
i = 0
for s in strategies:
    pf.plotting.plot_monthly_returns_heatmap(dict_results[s]['returns'], ax[i])
    ax[i].title.set_text(s)
    i += 1
pf.plotting.plot_monthly_returns_heatmap(df_constituents_ret['Benchmark'], ax[i])
ax[i].title.set_text('equal weighted')
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">
